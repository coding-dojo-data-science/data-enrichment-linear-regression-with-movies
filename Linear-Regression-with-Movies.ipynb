# %% [markdown]
# # Linear Regression with Movies

# %% [markdown]
# - 05/10/22

# %% [markdown]
# ### Topics/Concepts to Show

# %% [markdown]
# - Using `glob` for loading in all final files.
# - Linear Regression Assumptions
# - Preprocessing with/without scaling
# - Statsmodels OLS
# - QQPlot
# - Residual Plot

# %% [markdown]
# # Activity: Create a Linear Regression Model with Statsmodels for Revenue

# %%
import json
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats

# %% [markdown]
# ## Loading the Data

# %% [markdown]
# ### 📚 Finding & Loading Batches of Files with `glob`

# %%
## Checking what data we already in our Data folder using os.listdir
import os
FOLDER = 'Data/'
file_list = sorted(os.listdir(FOLDER))
file_list
# Out:
# ['.DS_Store',
#  'final_tmdb_data_2000.csv.gz',
#  'final_tmdb_data_2001.csv.gz',
#  'final_tmdb_data_2002.csv.gz',
#  'final_tmdb_data_2003.csv.gz',
#  'final_tmdb_data_2004.csv.gz',
#  'final_tmdb_data_2005.csv.gz',
#  'final_tmdb_data_2006.csv.gz',
#  'final_tmdb_data_2007.csv.gz',
#  'final_tmdb_data_2008.csv.gz',
#  'final_tmdb_data_2009.csv.gz',
#  'final_tmdb_data_2010.csv.gz',
#  'final_tmdb_data_2011.csv.gz',
#  'final_tmdb_data_2012.csv.gz',
#  'final_tmdb_data_2013.csv.gz',
#  'final_tmdb_data_2014.csv.gz',
#  'final_tmdb_data_2015.csv.gz',
#  'final_tmdb_data_2016.csv.gz',
#  'final_tmdb_data_2017.csv.gz',
#  'final_tmdb_data_2018.csv.gz',
#  'final_tmdb_data_2019.csv.gz',
#  'final_tmdb_data_2020.csv.gz',
#  'final_tmdb_data_2021.csv.gz',
#  'title_akas_cleaned.csv.gz',
#  'title_basics_cleaned.csv.gz',
#  'title_ratings_cleaned.csv.gz',
#  'tmdb_api_results_2000.json',
#  'tmdb_api_results_2001.json',
#  'tmdb_api_results_2002.json',
#  'tmdb_api_results_2003.json',
#  'tmdb_api_results_2004.json',
#  'tmdb_api_results_2005.json',
#  'tmdb_api_results_2006.json',
#  'tmdb_api_results_2007.json',
#  'tmdb_api_results_2008.json',
#  'tmdb_api_results_2009.json',
#  'tmdb_api_results_2010.json',
#  'tmdb_api_results_2011.json',
#  'tmdb_api_results_2012.json',
#  'tmdb_api_results_2013.json',
#  'tmdb_api_results_2014.json',
#  'tmdb_api_results_2015.json',
#  'tmdb_api_results_2016.json',
#  'tmdb_api_results_2017.json',
#  'tmdb_api_results_2018.json',
#  'tmdb_api_results_2019.json',
#  'tmdb_api_results_2020.json',
#  'tmdb_api_results_2021.json']

# %%
## Try loading in the first .csv.gz file from the list
pd.read_csv(file_list[1])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [9], in <cell line: 2>()
#       1 ## Try loading in the first .csv.gz file from the list
# ----> 2 pd.read_csv(file_list[1])
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/pandas/io/parsers/readers.py:586, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     571 kwds_defaults = _refine_defaults_read(
#     572     dialect,
#     573     delimiter,
#    (...)
#     582     defaults={"delimiter": ","},
#     583 )
#     584 kwds.update(kwds_defaults)
# --> 586 return _read(filepath_or_buffer, kwds)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/pandas/io/parsers/readers.py:482, in _read(filepath_or_buffer, kwds)
#     479 _validate_names(kwds.get("names", None))
#     481 # Create the parser.
# --> 482 parser = TextFileReader(filepath_or_buffer, **kwds)
#     484 if chunksize or iterator:
#     485     return parser
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/pandas/io/parsers/readers.py:811, in TextFileReader.__init__(self, f, engine, **kwds)
#     808 if "has_index_names" in kwds:
#     809     self.options["has_index_names"] = kwds["has_index_names"]
# --> 811 self._engine = self._make_engine(self.engine)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1040, in TextFileReader._make_engine(self, engine)
#    1036     raise ValueError(
#    1037         f"Unknown engine: {engine} (valid options are {mapping.keys()})"
#    1038     )
#    1039 # error: Too many arguments for "ParserBase"
# -> 1040 return mapping[engine](self.f, **self.options)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/pandas/io/parsers/c_parser_wrapper.py:51, in CParserWrapper.__init__(self, src, **kwds)
#      48 kwds["usecols"] = self.usecols
#      50 # open handles
# ---> 51 self._open_handles(src, kwds)
#      52 assert self.handles is not None
#      54 # Have to pass int, would break tests using TextReader directly otherwise :(
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/pandas/io/parsers/base_parser.py:222, in ParserBase._open_handles(self, src, kwds)
#     218 def _open_handles(self, src: FilePathOrBuffer, kwds: dict[str, Any]) -> None:
#     219     """
#     220     Let the readers open IOHandles after they are done with their potential raises.
#     221     """
# --> 222     self.handles = get_handle(
#     223         src,
#     224         "r",
#     225         encoding=kwds.get("encoding", None),
#     226         compression=kwds.get("compression", None),
#     227         memory_map=kwds.get("memory_map", False),
#     228         storage_options=kwds.get("storage_options", None),
#     229         errors=kwds.get("encoding_errors", "strict"),
#     230     )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/pandas/io/common.py:642, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640 if is_path:
#     641     assert isinstance(handle, str)
# --> 642     handle = gzip.GzipFile(
#     643         filename=handle,
#     644         mode=ioargs.mode,
#     645         **compression_args,
#     646     )
#     647 else:
#     648     handle = gzip.GzipFile(
#     649         # error: Argument "fileobj" to "GzipFile" has incompatible type
#     650         # "Union[str, Union[IO[Any], RawIOBase, BufferedIOBase, TextIOBase,
#    (...)
#     654         **compression_args,
#     655     )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/gzip.py:173, in GzipFile.__init__(self, filename, mode, compresslevel, fileobj, mtime)
#     171     mode += 'b'
#     172 if fileobj is None:
# --> 173     fileobj = self.myfileobj = builtins.open(filename, mode or 'rb')
#     174 if filename is None:
#     175     filename = getattr(fileobj, 'name', '')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'final_tmdb_data_2000.csv.gz'

# %% [markdown]
# > Why isn't it working?

# %%
## let's check the filepath 
file_list[1]
# Out:
# 'final_tmdb_data_2000.csv.gz'

# %%
## add the folder plus filename
FOLDER+ file_list[1]
# Out:
# 'Data/final_tmdb_data_2000.csv.gz'

# %%
## try read csv with folder plus filename
pd.read_csv(FOLDER+ file_list[1])
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 2     tt0113092    0.0                               NaN
# 3     tt0116391    0.0                               NaN
# 4     tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# ...         ...    ...                               ...
# 1193  tt6174238    0.0                               NaN
# 1194  tt7029820    0.0                               NaN
# 1195  tt7197642    0.0                               NaN
# 1196  tt7631368    0.0  /sF0gUHE0YzZNXYugTB2LFxJIppf.jpg
# 1197  tt7802790    0.0  /etxml2M8GQzb31jcH0cdA489WCX.jpg
#
#                                   belongs_to_collection      budget  \
# 0                                                   NaN         NaN
# 1                                                   NaN  10000000.0
# 2                                                   NaN         0.0
# 3                                                   NaN         0.0
# 4                                                   NaN    150000.0
# ...                                                 ...         ...
# 1193  {'id': 404302, 'name': 'Cold War Collection', ...         0.0
# 1194                                                NaN         0.0
# 1195                                                NaN         0.0
# 1196                                                NaN  10000000.0
# 1197                                                NaN         0.0
#
#                                                  genres  \
# 0                                                   NaN
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 2              [{'id': 878, 'name': 'Science Fiction'}]
# 3     [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 4     [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# ...                                                 ...
# 1193                      [{'id': 80, 'name': 'Crime'}]
# 1194                                                 []
# 1195                     [{'id': 35, 'name': 'Comedy'}]
# 1196                     [{'id': 27, 'name': 'Horror'}]
# 1197  [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
#
#                                   homepage        id original_language  \
# 0                                      NaN       NaN               NaN
# 1                                      NaN   62127.0                en
# 2                                      NaN  110977.0                en
# 3                                      NaN  442869.0                hi
# 4     http://www.wkw-inthemoodforlove.com/     843.0                cn
# ...                                    ...       ...               ...
# 1193                                   NaN  223878.0                en
# 1194                                   NaN  604889.0                en
# 1195                                   NaN  872676.0                en
# 1196                                   NaN   97186.0                fr
# 1197                                   NaN  610992.0                fa
#
#                original_title  ...     revenue  runtime  \
# 0                         NaN  ...         NaN      NaN
# 1             The Fantasticks  ...         0.0     86.0
# 2               For the Cause  ...         0.0    100.0
# 3                        Gang  ...         0.0    152.0
# 4                        花樣年華  ...  12854953.0     99.0
# ...                       ...  ...         ...      ...
# 1193                 Cold War  ...         0.0      0.0
# 1194     Scream For Christmas  ...         0.0     80.0
# 1195  Goodbye, Merry-Go-Round  ...         0.0     90.0
# 1196               I, Vampire  ...         0.0     85.0
# 1197                مومیایی ۳  ...         0.0     98.0
#
#                                        spoken_languages    status  \
# 0                                                   NaN       NaN
# 1     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3     [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 4     [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# ...                                                 ...       ...
# 1193  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# 1194                                                 []  Released
# 1195                                                 []  Released
# 1196  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1197  [{'english_name': 'Persian', 'iso_639_1': 'fa'...  Released
#
#                                                 tagline  \
# 0                                                   NaN
# 1         Try to remember the first time magic happened
# 2          The ultimate showdown on a forbidden planet.
# 3                                                   NaN
# 4     Feel the heat, keep the feeling burning, let t...
# ...                                                 ...
# 1193                                                NaN
# 1194                                                NaN
# 1195                                                NaN
# 1196                                                NaN
# 1197                                                NaN
#
#                         title  video  vote_average vote_count certification
# 0                         NaN    NaN           NaN        NaN           NaN
# 1             The Fantasticks    0.0           5.4       21.0           NaN
# 2               For the Cause    0.0           4.4        7.0           NaN
# 3                        Gang    0.0           0.0        0.0           NaN
# 4        In the Mood for Love    0.0           8.1     1868.0            PG
# ...                       ...    ...           ...        ...           ...
# 1193                 Cold War    0.0           2.0        2.0           NaN
# 1194     Scream For Christmas    0.0           0.0        0.0           NaN
# 1195  Goodbye, Merry-Go-Round    0.0           0.0        0.0           NaN
# 1196               I, Vampire    0.0           6.4        4.0            NR
# 1197              The Mummy 3    0.0           7.0        1.0           NaN
#
# [1198 rows x 26 columns]

# %% [markdown]
# - Now we would do that in a loop, and only want to open .csv.gz.
# - But there is a better way!
# >- Introducing `glob`
#     - Glob takes a filepath/query and will find every filename that matches the pattern provided.
#     - We use asterisks as wildcards in our query.

# %%
import glob
## Make a filepath query
q = FOLDER+"*.csv.gz"
print(q)

# %%
# Use glob.glob to get COMPLETE filepaths
file_list = glob.glob(q)
file_list
# Out:
# ['Data/final_tmdb_data_2006.csv.gz',
#  'Data/final_tmdb_data_2018.csv.gz',
#  'Data/final_tmdb_data_2014.csv.gz',
#  'Data/title_basics_cleaned.csv.gz',
#  'Data/final_tmdb_data_2008.csv.gz',
#  'Data/final_tmdb_data_2016.csv.gz',
#  'Data/final_tmdb_data_2004.csv.gz',
#  'Data/final_tmdb_data_2020.csv.gz',
#  'Data/title_ratings_cleaned.csv.gz',
#  'Data/final_tmdb_data_2000.csv.gz',
#  'Data/final_tmdb_data_2012.csv.gz',
#  'Data/final_tmdb_data_2010.csv.gz',
#  'Data/final_tmdb_data_2002.csv.gz',
#  'Data/final_tmdb_data_2019.csv.gz',
#  'Data/final_tmdb_data_2007.csv.gz',
#  'Data/final_tmdb_data_2015.csv.gz',
#  'Data/final_tmdb_data_2021.csv.gz',
#  'Data/final_tmdb_data_2017.csv.gz',
#  'Data/final_tmdb_data_2009.csv.gz',
#  'Data/final_tmdb_data_2005.csv.gz',
#  'Data/final_tmdb_data_2001.csv.gz',
#  'Data/final_tmdb_data_2013.csv.gz',
#  'Data/title_akas_cleaned.csv.gz',
#  'Data/final_tmdb_data_2011.csv.gz',
#  'Data/final_tmdb_data_2003.csv.gz']

# %%
# Use glob.glob to get COMPLETE filepaths
q = FOLDER+"final_*.csv.gz"
print(q)
file_list = sorted(glob.glob(q))
file_list
# Out:
# Data/final_*.csv.gz
# ['Data/final_tmdb_data_2000.csv.gz',
#  'Data/final_tmdb_data_2001.csv.gz',
#  'Data/final_tmdb_data_2002.csv.gz',
#  'Data/final_tmdb_data_2003.csv.gz',
#  'Data/final_tmdb_data_2004.csv.gz',
#  'Data/final_tmdb_data_2005.csv.gz',
#  'Data/final_tmdb_data_2006.csv.gz',
#  'Data/final_tmdb_data_2007.csv.gz',
#  'Data/final_tmdb_data_2008.csv.gz',
#  'Data/final_tmdb_data_2009.csv.gz']

# %% [markdown]
# > But where are the rest of the years?

# %%
## in a sub-folder
os.listdir(FOLDER+'2010-2021')
# Out:
# ['final_tmdb_data_2018.csv.gz',
#  'final_tmdb_data_2014.csv.gz',
#  'final_tmdb_data_2016.csv.gz',
#  'final_tmdb_data_2020.csv.gz',
#  'final_tmdb_data_2012.csv.gz',
#  'final_tmdb_data_2010.csv.gz',
#  'final_tmdb_data_2019.csv.gz',
#  'final_tmdb_data_2015.csv.gz',
#  'final_tmdb_data_2021.csv.gz',
#  'final_tmdb_data_2017.csv.gz',
#  'final_tmdb_data_2013.csv.gz',
#  'final_tmdb_data_2011.csv.gz']

# %% [markdown]
# - Recursive Searching with glob.
#     - add a `**/` in the middle of your query to grab any matches from all subfolders.

# %%
# Use glob.glob to get COMPLETE filepaths
q = FOLDER+"/**/final_*.csv.gz"
print(q)
file_list = sorted(glob.glob(q,recursive=True))
file_list
# Out:
# Data//**/final_*.csv.gz
# ['Data/2010-2021/final_tmdb_data_2010.csv.gz',
#  'Data/2010-2021/final_tmdb_data_2011.csv.gz',
#  'Data/2010-2021/final_tmdb_data_2012.csv.gz',
#  'Data/2010-2021/final_tmdb_data_2013.csv.gz',
#  'Data/2010-2021/final_tmdb_data_2014.csv.gz',
#  'Data/2010-2021/final_tmdb_data_2015.csv.gz',
#  'Data/2010-2021/final_tmdb_data_2016.csv.gz',
#  'Data/2010-2021/final_tmdb_data_2017.csv.gz',
#  'Data/2010-2021/final_tmdb_data_2018.csv.gz',
#  'Data/2010-2021/final_tmdb_data_2019.csv.gz',
#  'Data/2010-2021/final_tmdb_data_2020.csv.gz',
#  'Data/2010-2021/final_tmdb_data_2021.csv.gz',
#  'Data/final_tmdb_data_2000.csv.gz',
#  'Data/final_tmdb_data_2001.csv.gz',
#  'Data/final_tmdb_data_2002.csv.gz',
#  'Data/final_tmdb_data_2003.csv.gz',
#  'Data/final_tmdb_data_2004.csv.gz',
#  'Data/final_tmdb_data_2005.csv.gz',
#  'Data/final_tmdb_data_2006.csv.gz',
#  'Data/final_tmdb_data_2007.csv.gz',
#  'Data/final_tmdb_data_2008.csv.gz',
#  'Data/final_tmdb_data_2009.csv.gz']

# %%
## use a list comprehension to load in all files into 1 dataframe
df = pd.concat([pd.read_csv(f) for f in file_list])
df
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Input In [38], in <cell line: 2>()
#       1 ## use a list comprehension to load in all files into 1 dataframe
# ----> 2 df = pd.concat([pd.read_csv(f) for f in file_list])
#       3 df
#
# Input In [38], in <listcomp>(.0)
#       1 ## use a list comprehension to load in all files into 1 dataframe
# ----> 2 df = pd.concat([pd.read_csv(f) for f in file_list])
#       3 df
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/pandas/io/parsers/readers.py:586, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     571 kwds_defaults = _refine_defaults_read(
#     572     dialect,
#     573     delimiter,
#    (...)
#     582     defaults={"delimiter": ","},
#     583 )
#     584 kwds.update(kwds_defaults)
# --> 586 return _read(filepath_or_buffer, kwds)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/pandas/io/parsers/readers.py:488, in _read(filepath_or_buffer, kwds)
#     485     return parser
#     487 with parser:
# --> 488     return parser.read(nrows)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1047, in TextFileReader.read(self, nrows)
#    1045 def read(self, nrows=None):
#    1046     nrows = validate_integer("nrows", nrows)
# -> 1047     index, columns, col_dict = self._engine.read(nrows)
#    1049     if index is None:
#    1050         if col_dict:
#    1051             # Any column is actually fine:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/pandas/io/parsers/c_parser_wrapper.py:224, in CParserWrapper.read(self, nrows)
#     222 try:
#     223     if self.low_memory:
# --> 224         chunks = self._reader.read_low_memory(nrows)
#     225         # destructive to chunks
#     226         data = _concatenate_chunks(chunks)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/pandas/_libs/parsers.pyx:801, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/pandas/_libs/parsers.pyx:857, in pandas._libs.parsers.TextReader._read_rows()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/pandas/_libs/parsers.pyx:843, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/pandas/_libs/parsers.pyx:1925, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Buffer overflow caught - possible malformed input file.

# %% [markdown]
# - Dealing with ParserErrors with "possibly malformed files"
#
#     - for a reason I do not fully understand yet, some of the files I downloaded error if I try to read them.
#         - "ParserError: Error tokenizing data. C error: Buffer overflow caught - possible malformed input file.`
#     - After some googling, the fix was to add `lineterminator='\n'` to pd.read_csv

# %%
## use a list comprehension to load in all files into 1 dataframe
df = pd.concat([pd.read_csv(f,lineterminator='\n') for f in file_list])
df
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt0312305    0.0                               NaN
# 2     tt0326965    0.0  /xt2klJdKCVGXcoBGQrGfAS0aGDE.jpg
# 3     tt0331312    0.0                               NaN
# 4     tt0393049    0.0  /gc9FN5zohhzCt05RkejQIIPLtBl.jpg
# ...         ...    ...                               ...
# 2350  tt7661128    0.0                               NaN
# 2351  tt7786614    0.0                               NaN
# 2352  tt8170758    0.0                               NaN
# 2353  tt9330112    0.0                               NaN
# 2354  tt9556198    0.0                               NaN
#
#                                   belongs_to_collection    budget  \
# 0                                                   NaN       NaN
# 1                                                   NaN       0.0
# 2                                                   NaN       0.0
# 3                                                   NaN       0.0
# 4                                                   NaN  300000.0
# ...                                                 ...       ...
# 2350                                                NaN       0.0
# 2351                                                NaN       0.0
# 2352                                                NaN       0.0
# 2353                                                NaN       0.0
# 2354  {'id': 866148, 'name': 'Deep Sea Monster Raiga...       0.0
#
#                                                  genres  \
# 0                                                   NaN
# 1     [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# 2     [{'id': 53, 'name': 'Thriller'}, {'id': 9648, ...
# 3                                                    []
# 4     [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# ...                                                 ...
# 2350                   [{'id': 53, 'name': 'Thriller'}]
# 2351                                                 []
# 2352                                                 []
# 2353  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 2354  [{'id': 28, 'name': 'Action'}, {'id': 14, 'nam...
#
#                         homepage        id original_language  \
# 0                            NaN       NaN               NaN
# 1     http://www.qqthemovie.com/   23738.0                en
# 2       http://www.inmysleep.com   40048.0                en
# 3                            NaN  214026.0                en
# 4                            NaN  324352.0                en
# ...                          ...       ...               ...
# 2350                         NaN  595306.0                en
# 2351                         NaN  616643.0                en
# 2352                         NaN  513464.0                en
# 2353                         NaN  111622.0                ta
# 2354                         NaN  488412.0                ja
#
#                               original_title  ...   revenue  runtime  \
# 0                                        NaN  ...       NaN      NaN
# 1     Quantum Quest: A Cassini Space Odyssey  ...       0.0     45.0
# 2                                In My Sleep  ...       0.0     90.0
# 3                         This Wretched Life  ...       0.0      0.0
# 4                           Anderson's Cross  ...       0.0     98.0
# ...                                      ...  ...       ...      ...
# 2350                          Cold by Nature  ...  250000.0     77.0
# 2351                                 Ci qing  ...       0.0    100.0
# 2352         The Swell Season: One Step Away  ...       0.0     61.0
# 2353                    நினைத்தாலே இனிக்கும்  ...       0.0    145.0
# 2354                                   深海獣雷牙  ...       0.0     80.0
#
#                                        spoken_languages    status  \
# 0                                                   NaN       NaN
# 1     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3                                                    []  Released
# 4     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# ...                                                 ...       ...
# 2350  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2351                                                 []  Released
# 2352  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2353  [{'english_name': 'Tamil', 'iso_639_1': 'ta', ...  Released
# 2354  [{'english_name': 'Japanese', 'iso_639_1': 'ja...  Released
#
#                                                 tagline  \
# 0                                                   NaN
# 1                                                   NaN
# 2                            Sleepwalking Can Be Deadly
# 3                                                   NaN
# 4     Sometimes the boy next door is more than the b...
# ...                                                 ...
# 2350                                                NaN
# 2351                                                NaN
# 2352                                                NaN
# 2353                                                NaN
# 2354                                                NaN
#
#                                        title  video  vote_average vote_count  \
# 0                                        NaN    NaN           NaN        NaN
# 1     Quantum Quest: A Cassini Space Odyssey    0.0           8.4        7.0
# 2                                In My Sleep    0.0           5.5       31.0
# 3                         This Wretched Life    0.0           5.0        1.0
# 4                           Anderson's Cross    0.0           4.0        5.0
# ...                                      ...    ...           ...        ...
# 2350                          Cold by Nature    0.0           0.0        0.0
# 2351                                  Tattoo    0.0           5.0        1.0
# 2352         The Swell Season: One Step Away    0.0           0.0        0.0
# 2353                      Ninaithale Inikkum    0.0           4.0        1.0
# 2354                  Deep Sea Monster Raiga    0.0           7.7        3.0
#
#      certification
# 0              NaN
# 1              NaN
# 2            PG-13
# 3              NaN
# 4              NaN
# ...            ...
# 2350         PG-13
# 2351           NaN
# 2352            NR
# 2353           NaN
# 2354           NaN
#
# [60152 rows x 26 columns]

# %%
# remove ids that are 0
df = df.loc[ df['imdb_id']!='0']
df
# Out:
#         imdb_id  adult                     backdrop_path  \
# 1     tt0312305    0.0                               NaN
# 2     tt0326965    0.0  /xt2klJdKCVGXcoBGQrGfAS0aGDE.jpg
# 3     tt0331312    0.0                               NaN
# 4     tt0393049    0.0  /gc9FN5zohhzCt05RkejQIIPLtBl.jpg
# 5     tt0398286    0.0  /cWczNud8Y8i8ab0Z4bxos4myWYO.jpg
# ...         ...    ...                               ...
# 2350  tt7661128    0.0                               NaN
# 2351  tt7786614    0.0                               NaN
# 2352  tt8170758    0.0                               NaN
# 2353  tt9330112    0.0                               NaN
# 2354  tt9556198    0.0                               NaN
#
#                                   belongs_to_collection       budget  \
# 1                                                   NaN          0.0
# 2                                                   NaN          0.0
# 3                                                   NaN          0.0
# 4                                                   NaN     300000.0
# 5                                                   NaN  260000000.0
# ...                                                 ...          ...
# 2350                                                NaN          0.0
# 2351                                                NaN          0.0
# 2352                                                NaN          0.0
# 2353                                                NaN          0.0
# 2354  {'id': 866148, 'name': 'Deep Sea Monster Raiga...          0.0
#
#                                                  genres  \
# 1     [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# 2     [{'id': 53, 'name': 'Thriller'}, {'id': 9648, ...
# 3                                                    []
# 4     [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 5     [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# ...                                                 ...
# 2350                   [{'id': 53, 'name': 'Thriller'}]
# 2351                                                 []
# 2352                                                 []
# 2353  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 2354  [{'id': 28, 'name': 'Action'}, {'id': 14, 'nam...
#
#                                           homepage        id  \
# 1                       http://www.qqthemovie.com/   23738.0
# 2                         http://www.inmysleep.com   40048.0
# 3                                              NaN  214026.0
# 4                                              NaN  324352.0
# 5     http://disney.go.com/disneypictures/tangled/   38757.0
# ...                                            ...       ...
# 2350                                           NaN  595306.0
# 2351                                           NaN  616643.0
# 2352                                           NaN  513464.0
# 2353                                           NaN  111622.0
# 2354                                           NaN  488412.0
#
#      original_language                          original_title  ...  \
# 1                   en  Quantum Quest: A Cassini Space Odyssey  ...
# 2                   en                             In My Sleep  ...
# 3                   en                      This Wretched Life  ...
# 4                   en                        Anderson's Cross  ...
# 5                   en                                 Tangled  ...
# ...                ...                                     ...  ...
# 2350                en                          Cold by Nature  ...
# 2351                en                                 Ci qing  ...
# 2352                en         The Swell Season: One Step Away  ...
# 2353                ta                    நினைத்தாலே இனிக்கும்  ...
# 2354                ja                                   深海獣雷牙  ...
#
#           revenue  runtime                                   spoken_languages  \
# 1             0.0     45.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2             0.0     90.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 3             0.0      0.0                                                 []
# 4             0.0     98.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 5     592461732.0    100.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# ...           ...      ...                                                ...
# 2350     250000.0     77.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2351          0.0    100.0                                                 []
# 2352          0.0     61.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2353          0.0    145.0  [{'english_name': 'Tamil', 'iso_639_1': 'ta', ...
# 2354          0.0     80.0  [{'english_name': 'Japanese', 'iso_639_1': 'ja...
#
#         status                                            tagline  \
# 1     Released                                                NaN
# 2     Released                         Sleepwalking Can Be Deadly
# 3     Released                                                NaN
# 4     Released  Sometimes the boy next door is more than the b...
# 5     Released           They're taking adventure to new lengths.
# ...        ...                                                ...
# 2350  Released                                                NaN
# 2351  Released                                                NaN
# 2352  Released                                                NaN
# 2353  Released                                                NaN
# 2354  Released                                                NaN
#
#                                        title  video  vote_average vote_count  \
# 1     Quantum Quest: A Cassini Space Odyssey    0.0           8.4        7.0
# 2                                In My Sleep    0.0           5.5       31.0
# 3                         This Wretched Life    0.0           5.0        1.0
# 4                           Anderson's Cross    0.0           4.0        5.0
# 5                                    Tangled    0.0           7.6     9364.0
# ...                                      ...    ...           ...        ...
# 2350                          Cold by Nature    0.0           0.0        0.0
# 2351                                  Tattoo    0.0           5.0        1.0
# 2352         The Swell Season: One Step Away    0.0           0.0        0.0
# 2353                      Ninaithale Inikkum    0.0           4.0        1.0
# 2354                  Deep Sea Monster Raiga    0.0           7.7        3.0
#
#      certification
# 1              NaN
# 2            PG-13
# 3              NaN
# 4              NaN
# 5               PG
# ...            ...
# 2350         PG-13
# 2351           NaN
# 2352            NR
# 2353           NaN
# 2354           NaN
#
# [60130 rows x 26 columns]

# %%
df = df.reset_index(drop=True)
df
# Out:
#          imdb_id  adult                     backdrop_path  \
# 0      tt0312305    0.0                               NaN
# 1      tt0326965    0.0  /xt2klJdKCVGXcoBGQrGfAS0aGDE.jpg
# 2      tt0331312    0.0                               NaN
# 3      tt0393049    0.0  /gc9FN5zohhzCt05RkejQIIPLtBl.jpg
# 4      tt0398286    0.0  /cWczNud8Y8i8ab0Z4bxos4myWYO.jpg
# ...          ...    ...                               ...
# 60125  tt7661128    0.0                               NaN
# 60126  tt7786614    0.0                               NaN
# 60127  tt8170758    0.0                               NaN
# 60128  tt9330112    0.0                               NaN
# 60129  tt9556198    0.0                               NaN
#
#                                    belongs_to_collection       budget  \
# 0                                                    NaN          0.0
# 1                                                    NaN          0.0
# 2                                                    NaN          0.0
# 3                                                    NaN     300000.0
# 4                                                    NaN  260000000.0
# ...                                                  ...          ...
# 60125                                                NaN          0.0
# 60126                                                NaN          0.0
# 60127                                                NaN          0.0
# 60128                                                NaN          0.0
# 60129  {'id': 866148, 'name': 'Deep Sea Monster Raiga...          0.0
#
#                                                   genres  \
# 0      [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# 1      [{'id': 53, 'name': 'Thriller'}, {'id': 9648, ...
# 2                                                     []
# 3      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 4      [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# ...                                                  ...
# 60125                   [{'id': 53, 'name': 'Thriller'}]
# 60126                                                 []
# 60127                                                 []
# 60128  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 60129  [{'id': 28, 'name': 'Action'}, {'id': 14, 'nam...
#
#                                            homepage        id  \
# 0                        http://www.qqthemovie.com/   23738.0
# 1                          http://www.inmysleep.com   40048.0
# 2                                               NaN  214026.0
# 3                                               NaN  324352.0
# 4      http://disney.go.com/disneypictures/tangled/   38757.0
# ...                                             ...       ...
# 60125                                           NaN  595306.0
# 60126                                           NaN  616643.0
# 60127                                           NaN  513464.0
# 60128                                           NaN  111622.0
# 60129                                           NaN  488412.0
#
#       original_language                          original_title  ...  \
# 0                    en  Quantum Quest: A Cassini Space Odyssey  ...
# 1                    en                             In My Sleep  ...
# 2                    en                      This Wretched Life  ...
# 3                    en                        Anderson's Cross  ...
# 4                    en                                 Tangled  ...
# ...                 ...                                     ...  ...
# 60125                en                          Cold by Nature  ...
# 60126                en                                 Ci qing  ...
# 60127                en         The Swell Season: One Step Away  ...
# 60128                ta                    நினைத்தாலே இனிக்கும்  ...
# 60129                ja                                   深海獣雷牙  ...
#
#            revenue  runtime  \
# 0              0.0     45.0
# 1              0.0     90.0
# 2              0.0      0.0
# 3              0.0     98.0
# 4      592461732.0    100.0
# ...            ...      ...
# 60125     250000.0     77.0
# 60126          0.0    100.0
# 60127          0.0     61.0
# 60128          0.0    145.0
# 60129          0.0     80.0
#
#                                         spoken_languages    status  \
# 0      [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1      [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2                                                     []  Released
# 3      [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4      [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# ...                                                  ...       ...
# 60125  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 60126                                                 []  Released
# 60127  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 60128  [{'english_name': 'Tamil', 'iso_639_1': 'ta', ...  Released
# 60129  [{'english_name': 'Japanese', 'iso_639_1': 'ja...  Released
#
#                                                  tagline  \
# 0                                                    NaN
# 1                             Sleepwalking Can Be Deadly
# 2                                                    NaN
# 3      Sometimes the boy next door is more than the b...
# 4               They're taking adventure to new lengths.
# ...                                                  ...
# 60125                                                NaN
# 60126                                                NaN
# 60127                                                NaN
# 60128                                                NaN
# 60129                                                NaN
#
#                                         title  video  vote_average vote_count  \
# 0      Quantum Quest: A Cassini Space Odyssey    0.0           8.4        7.0
# 1                                 In My Sleep    0.0           5.5       31.0
# 2                          This Wretched Life    0.0           5.0        1.0
# 3                            Anderson's Cross    0.0           4.0        5.0
# 4                                     Tangled    0.0           7.6     9364.0
# ...                                       ...    ...           ...        ...
# 60125                          Cold by Nature    0.0           0.0        0.0
# 60126                                  Tattoo    0.0           5.0        1.0
# 60127         The Swell Season: One Step Away    0.0           0.0        0.0
# 60128                      Ninaithale Inikkum    0.0           4.0        1.0
# 60129                  Deep Sea Monster Raiga    0.0           7.7        3.0
#
#       certification
# 0               NaN
# 1             PG-13
# 2               NaN
# 3               NaN
# 4                PG
# ...             ...
# 60125         PG-13
# 60126           NaN
# 60127            NR
# 60128           NaN
# 60129           NaN
#
# [60130 rows x 26 columns]

# %%
## saving the combined csv to disk
df.to_csv(FOLDER+'combined_tmdb_data.csv.gz',compression='gzip',index=False)

# %%
df = pd.read_csv(FOLDER+'combined_tmdb_data.csv.gz',lineterminator='\n')
df
# Out:
#          imdb_id  adult                     backdrop_path  \
# 0      tt0312305    0.0                               NaN
# 1      tt0326965    0.0  /xt2klJdKCVGXcoBGQrGfAS0aGDE.jpg
# 2      tt0331312    0.0                               NaN
# 3      tt0393049    0.0  /gc9FN5zohhzCt05RkejQIIPLtBl.jpg
# 4      tt0398286    0.0  /cWczNud8Y8i8ab0Z4bxos4myWYO.jpg
# ...          ...    ...                               ...
# 60125  tt7661128    0.0                               NaN
# 60126  tt7786614    0.0                               NaN
# 60127  tt8170758    0.0                               NaN
# 60128  tt9330112    0.0                               NaN
# 60129  tt9556198    0.0                               NaN
#
#                                    belongs_to_collection       budget  \
# 0                                                    NaN          0.0
# 1                                                    NaN          0.0
# 2                                                    NaN          0.0
# 3                                                    NaN     300000.0
# 4                                                    NaN  260000000.0
# ...                                                  ...          ...
# 60125                                                NaN          0.0
# 60126                                                NaN          0.0
# 60127                                                NaN          0.0
# 60128                                                NaN          0.0
# 60129  {'id': 866148, 'name': 'Deep Sea Monster Raiga...          0.0
#
#                                                   genres  \
# 0      [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# 1      [{'id': 53, 'name': 'Thriller'}, {'id': 9648, ...
# 2                                                     []
# 3      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 4      [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# ...                                                  ...
# 60125                   [{'id': 53, 'name': 'Thriller'}]
# 60126                                                 []
# 60127                                                 []
# 60128  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 60129  [{'id': 28, 'name': 'Action'}, {'id': 14, 'nam...
#
#                                            homepage        id  \
# 0                        http://www.qqthemovie.com/   23738.0
# 1                          http://www.inmysleep.com   40048.0
# 2                                               NaN  214026.0
# 3                                               NaN  324352.0
# 4      http://disney.go.com/disneypictures/tangled/   38757.0
# ...                                             ...       ...
# 60125                                           NaN  595306.0
# 60126                                           NaN  616643.0
# 60127                                           NaN  513464.0
# 60128                                           NaN  111622.0
# 60129                                           NaN  488412.0
#
#       original_language                          original_title  ...  \
# 0                    en  Quantum Quest: A Cassini Space Odyssey  ...
# 1                    en                             In My Sleep  ...
# 2                    en                      This Wretched Life  ...
# 3                    en                        Anderson's Cross  ...
# 4                    en                                 Tangled  ...
# ...                 ...                                     ...  ...
# 60125                en                          Cold by Nature  ...
# 60126                en                                 Ci qing  ...
# 60127                en         The Swell Season: One Step Away  ...
# 60128                ta                    நினைத்தாலே இனிக்கும்  ...
# 60129                ja                                   深海獣雷牙  ...
#
#            revenue  runtime  \
# 0              0.0     45.0
# 1              0.0     90.0
# 2              0.0      0.0
# 3              0.0     98.0
# 4      592461732.0    100.0
# ...            ...      ...
# 60125     250000.0     77.0
# 60126          0.0    100.0
# 60127          0.0     61.0
# 60128          0.0    145.0
# 60129          0.0     80.0
#
#                                         spoken_languages    status  \
# 0      [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1      [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2                                                     []  Released
# 3      [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4      [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# ...                                                  ...       ...
# 60125  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 60126                                                 []  Released
# 60127  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 60128  [{'english_name': 'Tamil', 'iso_639_1': 'ta', ...  Released
# 60129  [{'english_name': 'Japanese', 'iso_639_1': 'ja...  Released
#
#                                                  tagline  \
# 0                                                    NaN
# 1                             Sleepwalking Can Be Deadly
# 2                                                    NaN
# 3      Sometimes the boy next door is more than the b...
# 4               They're taking adventure to new lengths.
# ...                                                  ...
# 60125                                                NaN
# 60126                                                NaN
# 60127                                                NaN
# 60128                                                NaN
# 60129                                                NaN
#
#                                         title  video  vote_average vote_count  \
# 0      Quantum Quest: A Cassini Space Odyssey    0.0           8.4        7.0
# 1                                 In My Sleep    0.0           5.5       31.0
# 2                          This Wretched Life    0.0           5.0        1.0
# 3                            Anderson's Cross    0.0           4.0        5.0
# 4                                     Tangled    0.0           7.6     9364.0
# ...                                       ...    ...           ...        ...
# 60125                          Cold by Nature    0.0           0.0        0.0
# 60126                                  Tattoo    0.0           5.0        1.0
# 60127         The Swell Season: One Step Away    0.0           0.0        0.0
# 60128                      Ninaithale Inikkum    0.0           4.0        1.0
# 60129                  Deep Sea Monster Raiga    0.0           7.7        3.0
#
#       certification
# 0               NaN
# 1             PG-13
# 2               NaN
# 3               NaN
# 4                PG
# ...             ...
# 60125         PG-13
# 60126           NaN
# 60127            NR
# 60128           NaN
# 60129           NaN
#
# [60130 rows x 26 columns]
