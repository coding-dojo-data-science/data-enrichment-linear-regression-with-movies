# %% [markdown]
# # Linear Regression with Statsmodels for Movie Revenue

# %% [markdown]
# - 06/13/22

# %% [markdown]
# ## Activity: Create a Linear Regression Model with Statsmodels for Revenue

# %% [markdown]
# - Today we will be working with JUST the data data from the TMDB API for years 2000-2021.
#     - We will prepare the data for modeling
#         - Some feature engineering
#         - Our usual Preprocessing
#         - New steps for statsmodels!
#     - We will fit a statsmodels linear regression.
#     - We Will inspect the model summary.
#     - We will create the visualizations to check assumptions about the residuals.
#
#
#
# - Next class we will continue this activity.
#     - We will better check all 4 assumptions.
#     - We will discuss tactics for dealing with violations of the assumptions.
#     - We will use our coefficients to make stakeholder recommendations.

# %% [markdown]
# ### Concepts Demonstrated

# %% [markdown]
# - [ ] Using `glob` for loading in all final files.
# - [ ] Statsmodels OLS
# - [ ] QQ-Plot
# - [ ] Residual Plot

# %% [markdown]
# # Loading the Data

# %%
import json
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats

import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.compose import make_column_transformer, make_column_selector, ColumnTransformer
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
## fixing random for lesson generation
np.random.seed(321)

# %%
pd.set_option('display.max_columns',100)

# %% [markdown]
# ### 📚 Finding & Loading Batches of Files with `glob`

# %%
## Checking what data we already in our Data folder using os.listdir
import os
FOLDER = '../Data/'
file_list = sorted(os.listdir(FOLDER))
file_list
# Out:
# ['.DS_Store',
#  '.ipynb_checkpoints',
#  '2010-2021',
#  'combined_all_data.csv.gz',
#  'combined_tmdb_data.csv.gz',
#  'final_tmdb_data_2000.csv.gz',
#  'final_tmdb_data_2001.csv.gz',
#  'final_tmdb_data_2002.csv.gz',
#  'final_tmdb_data_2003.csv.gz',
#  'final_tmdb_data_2004.csv.gz',
#  'final_tmdb_data_2005.csv.gz',
#  'final_tmdb_data_2006.csv.gz',
#  'final_tmdb_data_2007.csv.gz',
#  'final_tmdb_data_2008.csv.gz',
#  'final_tmdb_data_2009.csv.gz',
#  'title_akas_cleaned.csv.gz',
#  'title_basics_cleaned.csv.gz',
#  'title_ratings_cleaned.csv.gz',
#  'tmdb_api_results_2000.json',
#  'tmdb_api_results_2001.json',
#  'tmdb_api_results_2002.json',
#  'tmdb_api_results_2003.json',
#  'tmdb_api_results_2004.json',
#  'tmdb_api_results_2005.json',
#  'tmdb_api_results_2006.json',
#  'tmdb_api_results_2007.json',
#  'tmdb_api_results_2008.json',
#  'tmdb_api_results_2009.json',
#  'tmdb_api_results_2010.json',
#  'tmdb_api_results_2011.json',
#  'tmdb_api_results_2012.json',
#  'tmdb_api_results_2013.json',
#  'tmdb_api_results_2014.json',
#  'tmdb_api_results_2015.json',
#  'tmdb_api_results_2016.json',
#  'tmdb_api_results_2017.json',
#  'tmdb_api_results_2018.json',
#  'tmdb_api_results_2019.json',
#  'tmdb_api_results_2020.json',
#  'tmdb_api_results_2021.json']

# %%
# ## Try loading in the first .csv.gz file from the list
# pd.read_csv(file_list[5])# lineterminator='\n')

# %% [markdown]
# > Why isn't it working?

# %%
## let's check the filepath

# %%
## add the folder plus filename

# %%
## try read csv with folder plus filename

# %% [markdown]
# - Now we would do that in a loop, and only want to open .csv.gz.
# - But there is a better way!
# >- Introducing `glob`
#     - Glob takes a filepath/query and will find every filename that matches the pattern provided.
#     - We use asterisks as wildcards in our query.

# %%
import glob
## Make a filepath query
q = FOLDER+"final*.csv.gz"
q
# Out:
# '../Data/final*.csv.gz'

# %%
# Use glob.glob to get COMPLETE filepaths
file_list = glob.glob(q)
file_list
# Out:
# ['../Data/final_tmdb_data_2006.csv.gz',
#  '../Data/final_tmdb_data_2008.csv.gz',
#  '../Data/final_tmdb_data_2004.csv.gz',
#  '../Data/final_tmdb_data_2000.csv.gz',
#  '../Data/final_tmdb_data_2002.csv.gz',
#  '../Data/final_tmdb_data_2007.csv.gz',
#  '../Data/final_tmdb_data_2009.csv.gz',
#  '../Data/final_tmdb_data_2005.csv.gz',
#  '../Data/final_tmdb_data_2001.csv.gz',
#  '../Data/final_tmdb_data_2003.csv.gz']

# %%
pd.read_csv(file_list[0], lineterminator='\n')
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt0144280    0.0                               NaN
# 2     tt0197633    0.0  /1hGrzTajJ5JC6VfPzrUj8Gj5t5k.jpg
# 3     tt0204250    0.0  /qKiOZMJH9Riqlk2SkUOgSMZHHJu.jpg
# 4     tt0206634    0.0  /z8FzomPxfCb2nv827VWLSI6oYiB.jpg
# ...         ...    ...                               ...
# 1790  tt7503878    0.0                               NaN
# 1791  tt7775532    0.0                               NaN
# 1792  tt8165062    0.0                               NaN
# 1793  tt8784950    0.0                               NaN
# 1794  tt9377936    0.0                               NaN
#
#                                   belongs_to_collection      budget  \
# 0                                                   NaN         NaN
# 1                                                   NaN    100000.0
# 2                                                   NaN         0.0
# 3                                                   NaN         0.0
# 4                                                   NaN  76000000.0
# ...                                                 ...         ...
# 1790                                                NaN         0.0
# 1791                                                NaN         0.0
# 1792  {'id': 800116, 'name': 'Survive Girls', 'poste...         0.0
# 1793                                                NaN         0.0
# 1794                                                NaN         0.0
#
#                                                  genres  \
# 0                                                   NaN
# 1                                                    []
# 2     [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 3     [{'id': 9648, 'name': 'Mystery'}, {'id': 35, '...
# 4     [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# ...                                                 ...
# 1790                      [{'id': 18, 'name': 'Drama'}]
# 1791                     [{'id': 27, 'name': 'Horror'}]
# 1792                     [{'id': 27, 'name': 'Horror'}]
# 1793                                                 []
# 1794                      [{'id': 18, 'name': 'Drama'}]
#
#                                                homepage        id  \
# 0                                                   NaN       NaN
# 1                                                   NaN   30356.0
# 2                                                   NaN   58520.0
# 3                                                   NaN  459563.0
# 4     http://www.universalstudiosentertainment.com/c...    9693.0
# ...                                                 ...       ...
# 1790                                                NaN  481010.0
# 1791        https://www.youtube.com/watch?v=_neakMwmoCY  939621.0
# 1792                                                NaN  800112.0
# 1793                                                NaN  939503.0
# 1794                                                NaN  709352.0
#
#      original_language                 original_title  \
# 0                  NaN                            NaN
# 1                   en  Whispers from a Shallow Grave
# 2                   en         Live Freaky Die Freaky
# 3                   en          Death of a Saleswoman
# 4                   en                Children of Men
# ...                ...                            ...
# 1790                fr      Vintage Erotica Anno 1920
# 1791                en               Neck of da Woodz
# 1792                ja                        Sabaibu
# 1793                zh                           浅蓝深蓝
# 1794                en            Sexual Incantations
#
#                                                overview  popularity  \
# 0                                                   NaN         NaN
# 1     When a beautiful photo model disappears, polic...       1.176
# 2     It is the year 3069 and the Earth has been rob...       3.131
# 3     Top-ranking RubberTubber saleswoman Agatha J. ...       0.600
# 4     In 2027, in a chaotic world in which humans ca...      19.318
# ...                                                 ...         ...
# 1790  19 remastered French short films from the  20'...       0.840
# 1791  Five brothas run outta gas in the sticks and r...       0.600
# 1792  Experience two erotic tales of survival that w...       1.343
# 1793                                                NaN       0.600
# 1794  Darian is a sexually repressed wildcat waiting...       1.181
#
#                            poster_path  \
# 0                                  NaN
# 1     /cjRqAh3u2Z0MBx9GtT1k7Z9732w.jpg
# 2     /3QKPZ9SzMcBdqkKdSitQbmRqB2l.jpg
# 3     /tIfllOpkhZl5sbqZd1X77iiaJDj.jpg
# 4     /k9IAS4TehZFcKi4HVByxZNPfqex.jpg
# ...                                ...
# 1790  /iVmJ5s3bgHaqCaDTBQ6mh4cxqgx.jpg
# 1791  /AgSO3MvqVbqKqBtQjWPmgAEteNW.jpg
# 1792  /8V80ADHG6UqpNwUWL8v7pAWnW3S.jpg
# 1793  /baG7vzBr1yAwVHd7nYH1SmAFVBs.jpg
# 1794  /day4i8fsOegruDndPb0Ggr1p1sM.jpg
#
#                                    production_companies  \
# 0                                                   NaN
# 1                                                    []
# 2                                                    []
# 3     [{'id': 90905, 'logo_path': None, 'name': 'Gir...
# 4     [{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKX...
# ...                                                 ...
# 1790                                                 []
# 1791  [{'id': 170026, 'logo_path': None, 'name': '2 ...
# 1792                                                 []
# 1793                                                 []
# 1794  [{'id': 5428, 'logo_path': None, 'name': 'Secr...
#
#                                    production_countries release_date  \
# 0                                                   NaN          NaN
# 1     [{'iso_3166_1': 'US', 'name': 'United States o...   1997-01-01
# 2     [{'iso_3166_1': 'US', 'name': 'United States o...   2006-01-31
# 3     [{'iso_3166_1': 'US', 'name': 'United States o...   2006-09-18
# 4     [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   2006-09-22
# ...                                                 ...          ...
# 1790           [{'iso_3166_1': 'FR', 'name': 'France'}]   2006-08-01
# 1791                                                 []          NaN
# 1792            [{'iso_3166_1': 'JP', 'name': 'Japan'}]   2010-10-26
# 1793                                                 []   2006-01-31
# 1794  [{'iso_3166_1': 'US', 'name': 'United States o...   2006-01-01
#
#          revenue  runtime                                   spoken_languages  \
# 0            NaN      NaN                                                NaN
# 1            0.0     90.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2            0.0     75.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 3            0.0     77.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 4     70595464.0    109.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# ...          ...      ...                                                ...
# 1790         0.0     90.0  [{'english_name': 'French', 'iso_639_1': 'fr',...
# 1791         0.0     72.0                                                 []
# 1792         0.0     86.0  [{'english_name': 'Japanese', 'iso_639_1': 'ja...
# 1793         0.0      0.0                                                 []
# 1794         0.0     80.0  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#         status                                            tagline  \
# 0          NaN                                                NaN
# 1     Released                                                NaN
# 2     Released                                                NaN
# 3     Released  6 housewives. 1 dead body. A trunk full of pla...
# 4     Released                  The future's a thing of the past.
# ...        ...                                                ...
# 1790  Released                                                NaN
# 1791  Released  Survival is all that matters when Boyz from th...
# 1792  Released                                                NaN
# 1793  Released                                                NaN
# 1794  Released                                                NaN
#
#                               title  video  vote_average  vote_count  \
# 0                               NaN    NaN           NaN         NaN
# 1     Whispers from a Shallow Grave    0.0           2.0         2.0
# 2            Live Freaky Die Freaky    0.0           3.8         8.0
# 3             Death of a Saleswoman    0.0           3.0         1.0
# 4                   Children of Men    0.0           7.6      5779.0
# ...                             ...    ...           ...         ...
# 1790      Vintage Erotica Anno 1920    0.0           9.0         1.0
# 1791               Neck of da Woodz    0.0          10.0         1.0
# 1792                  Survive Girls    0.0           0.0         0.0
# 1793                           浅蓝深蓝    0.0           0.0         0.0
# 1794            Sexual Incantations    0.0           2.0         1.0
#
#      certification
# 0              NaN
# 1              NaN
# 2               NR
# 3              NaN
# 4                R
# ...            ...
# 1790           NaN
# 1791           NaN
# 1792           NaN
# 1793           NaN
# 1794            NR
#
# [1795 rows x 26 columns]

# %%
# Use glob.glob to get COMPLETE filepaths

# %% [markdown]
# > But where are the rest of the years?

# %%
## in a sub-folder

# %% [markdown]
# - Recursive Searching with glob.
#     - add a `**/` in the middle of your query to grab any matches from all subfolders.

# %%
# Use glob.glob to get COMPLETE filepaths
q = FOLDER+"**/final*.csv.gz"
file_list = glob.glob(q, recursive=True)
file_list
# Out:
# ['../Data/final_tmdb_data_2006.csv.gz',
#  '../Data/final_tmdb_data_2008.csv.gz',
#  '../Data/final_tmdb_data_2004.csv.gz',
#  '../Data/final_tmdb_data_2000.csv.gz',
#  '../Data/final_tmdb_data_2002.csv.gz',
#  '../Data/final_tmdb_data_2007.csv.gz',
#  '../Data/final_tmdb_data_2009.csv.gz',
#  '../Data/final_tmdb_data_2005.csv.gz',
#  '../Data/final_tmdb_data_2001.csv.gz',
#  '../Data/final_tmdb_data_2003.csv.gz',
#  '../Data/2010-2021/final_tmdb_data_2018.csv.gz',
#  '../Data/2010-2021/final_tmdb_data_2014.csv.gz',
#  '../Data/2010-2021/final_tmdb_data_2016.csv.gz',
#  '../Data/2010-2021/final_tmdb_data_2020.csv.gz',
#  '../Data/2010-2021/final_tmdb_data_2012.csv.gz',
#  '../Data/2010-2021/final_tmdb_data_2010.csv.gz',
#  '../Data/2010-2021/final_tmdb_data_2019.csv.gz',
#  '../Data/2010-2021/final_tmdb_data_2015.csv.gz',
#  '../Data/2010-2021/final_tmdb_data_2021.csv.gz',
#  '../Data/2010-2021/final_tmdb_data_2017.csv.gz',
#  '../Data/2010-2021/final_tmdb_data_2013.csv.gz',
#  '../Data/2010-2021/final_tmdb_data_2011.csv.gz']

# %%
df_list = []
for file in file_list:
    temp_df = pd.read_csv(file, lineterminator='\n')
    df_list.append(temp_df)
len(df_list)
# Out:
# 22

# %%
# pd.concat(df_list)

# %%
# ## use a list comprehension to load in all files into 1 dataframe
df = pd.concat([ pd.read_csv(file, lineterminator='\n') for file in file_list])
df
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt0144280    0.0                               NaN
# 2     tt0197633    0.0  /1hGrzTajJ5JC6VfPzrUj8Gj5t5k.jpg
# 3     tt0204250    0.0  /qKiOZMJH9Riqlk2SkUOgSMZHHJu.jpg
# 4     tt0206634    0.0  /z8FzomPxfCb2nv827VWLSI6oYiB.jpg
# ...         ...    ...                               ...
# 2893  tt9282946    0.0                               NaN
# 2894  tt9385434    0.0                               NaN
# 2895  tt9452878    0.0                               NaN
# 2896  tt9519786    0.0  /oof2qSqrH1PAe9yEaBnId1P326G.jpg
# 2897  tt9547900    0.0                               NaN
#
#      belongs_to_collection      budget  \
# 0                      NaN         NaN
# 1                      NaN    100000.0
# 2                      NaN         0.0
# 3                      NaN         0.0
# 4                      NaN  76000000.0
# ...                    ...         ...
# 2893                   NaN         0.0
# 2894                   NaN         0.0
# 2895                   NaN         0.0
# 2896                   NaN         0.0
# 2897                   NaN         0.0
#
#                                                  genres  \
# 0                                                   NaN
# 1                                                    []
# 2     [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 3     [{'id': 9648, 'name': 'Mystery'}, {'id': 35, '...
# 4     [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# ...                                                 ...
# 2893                     [{'id': 35, 'name': 'Comedy'}]
# 2894                      [{'id': 18, 'name': 'Drama'}]
# 2895  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2896                      [{'id': 18, 'name': 'Drama'}]
# 2897  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
#
#                                                homepage        id  \
# 0                                                   NaN       NaN
# 1                                                   NaN   30356.0
# 2                                                   NaN   58520.0
# 3                                                   NaN  459563.0
# 4     http://www.universalstudiosentertainment.com/c...    9693.0
# ...                                                 ...       ...
# 2893                                                NaN  490059.0
# 2894                                                NaN  566831.0
# 2895                                                NaN  108925.0
# 2896                                                NaN  874426.0
# 2897                                                NaN  922954.0
#
#      original_language                 original_title  \
# 0                  NaN                            NaN
# 1                   en  Whispers from a Shallow Grave
# 2                   en         Live Freaky Die Freaky
# 3                   en          Death of a Saleswoman
# 4                   en                Children of Men
# ...                ...                            ...
# 2893                ko                           도약선생
# 2894                ja                       お米とおっぱい。
# 2895                en              The Wrong Ferarri
# 2896                zh                    North point
# 2897                zh                           百年情书
#
#                                                overview  popularity  \
# 0                                                   NaN         NaN
# 1     When a beautiful photo model disappears, polic...       1.176
# 2     It is the year 3069 and the Earth has been rob...       3.131
# 3     Top-ranking RubberTubber saleswoman Agatha J. ...       0.600
# 4     In 2027, in a chaotic world in which humans ca...      19.318
# ...                                                 ...         ...
# 2893  Won-sik is kicked out by her roommate Woo-jung...       0.914
# 2894  What would you choose, between rice and boobs,...       1.400
# 2895  The Wrong Ferarri is a feature-film written an...       1.884
# 2896                                                NaN       1.343
# 2897                                                NaN       1.343
#
#                            poster_path  \
# 0                                  NaN
# 1     /cjRqAh3u2Z0MBx9GtT1k7Z9732w.jpg
# 2     /3QKPZ9SzMcBdqkKdSitQbmRqB2l.jpg
# 3     /tIfllOpkhZl5sbqZd1X77iiaJDj.jpg
# 4     /k9IAS4TehZFcKi4HVByxZNPfqex.jpg
# ...                                ...
# 2893  /rXrDkS3Mpow9q915zrmiH3stAn5.jpg
# 2894  /4cmlMKKDkbCxm2Kjs4gfmTFL7XE.jpg
# 2895                               NaN
# 2896  /ynnOmcXSIQlWnCykRWA3o0rPsAv.jpg
# 2897  /aeaGbLhM42ZpRyII6groNe4Hg5I.jpg
#
#                                    production_companies  \
# 0                                                   NaN
# 1                                                    []
# 2                                                    []
# 3     [{'id': 90905, 'logo_path': None, 'name': 'Gir...
# 4     [{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKX...
# ...                                                 ...
# 2893                                                 []
# 2894  [{'id': 11725, 'logo_path': '/3OZxd70DZ1LbVelm...
# 2895                                                 []
# 2896  [{'id': 158558, 'logo_path': None, 'name': '上海...
# 2897                                                 []
#
#                                    production_countries release_date  \
# 0                                                   NaN          NaN
# 1     [{'iso_3166_1': 'US', 'name': 'United States o...   1997-01-01
# 2     [{'iso_3166_1': 'US', 'name': 'United States o...   2006-01-31
# 3     [{'iso_3166_1': 'US', 'name': 'United States o...   2006-09-18
# 4     [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   2006-09-22
# ...                                                 ...          ...
# 2893      [{'iso_3166_1': 'KR', 'name': 'South Korea'}]   2011-06-30
# 2894            [{'iso_3166_1': 'JP', 'name': 'Japan'}]   2011-07-01
# 2895  [{'iso_3166_1': 'US', 'name': 'United States o...   2011-04-04
# 2896                                                 []   2011-11-04
# 2897                                                 []   2011-05-13
#
#          revenue  runtime                                   spoken_languages  \
# 0            NaN      NaN                                                NaN
# 1            0.0     90.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2            0.0     75.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 3            0.0     77.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 4     70595464.0    109.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# ...          ...      ...                                                ...
# 2893         0.0     65.0  [{'english_name': 'Korean', 'iso_639_1': 'ko',...
# 2894         0.0    102.0  [{'english_name': 'Japanese', 'iso_639_1': 'ja...
# 2895         0.0     72.0                                                 []
# 2896         0.0      0.0                                                 []
# 2897         0.0      0.0  [{'english_name': 'Mandarin', 'iso_639_1': 'zh...
#
#         status                                            tagline  \
# 0          NaN                                                NaN
# 1     Released                                                NaN
# 2     Released                                                NaN
# 3     Released  6 housewives. 1 dead body. A trunk full of pla...
# 4     Released                  The future's a thing of the past.
# ...        ...                                                ...
# 2893  Released                                                NaN
# 2894  Released                                                NaN
# 2895  Released                                                NaN
# 2896  Released                                                NaN
# 2897  Released                                                NaN
#
#                               title  video  vote_average  vote_count  \
# 0                               NaN    NaN           NaN         NaN
# 1     Whispers from a Shallow Grave    0.0           2.0         2.0
# 2            Live Freaky Die Freaky    0.0           3.8         8.0
# 3             Death of a Saleswoman    0.0           3.0         1.0
# 4                   Children of Men    0.0           7.6      5779.0
# ...                             ...    ...           ...         ...
# 2893                       Dr. Jump    0.0           7.0         1.0
# 2894                 Rice and Boobs    0.0           0.0         0.0
# 2895              The Wrong Ferarri    0.0           2.0         1.0
# 2896                    North point    0.0           0.0         0.0
# 2897                           百年情书    0.0           0.0         0.0
#
#      certification
# 0              NaN
# 1              NaN
# 2               NR
# 3              NaN
# 4                R
# ...            ...
# 2893           NaN
# 2894           NaN
# 2895           NaN
# 2896           NaN
# 2897           NaN
#
# [60152 rows x 26 columns]

# %% [markdown]
# - Dealing with ParserErrors with "possibly malformed files"
#
#     - for a reason I do not fully understand yet, some of the files I downloaded error if I try to read them.
#         - "ParserError: Error tokenizing data. C error: Buffer overflow caught - possible malformed input file.`
#     - After some googling, the fix was to add `lineterminator='\n'` to pd.read_csv

# %%
# remove ids that are 0
df = df.loc[ df['imdb_id']!='0']
df
# Out:
#         imdb_id  adult                     backdrop_path  \
# 1     tt0144280    0.0                               NaN
# 2     tt0197633    0.0  /1hGrzTajJ5JC6VfPzrUj8Gj5t5k.jpg
# 3     tt0204250    0.0  /qKiOZMJH9Riqlk2SkUOgSMZHHJu.jpg
# 4     tt0206634    0.0  /z8FzomPxfCb2nv827VWLSI6oYiB.jpg
# 5     tt0244521    0.0  /4W53mm2nvOtiOuPNW2oiBm9pmUZ.jpg
# ...         ...    ...                               ...
# 2893  tt9282946    0.0                               NaN
# 2894  tt9385434    0.0                               NaN
# 2895  tt9452878    0.0                               NaN
# 2896  tt9519786    0.0  /oof2qSqrH1PAe9yEaBnId1P326G.jpg
# 2897  tt9547900    0.0                               NaN
#
#      belongs_to_collection      budget  \
# 1                      NaN    100000.0
# 2                      NaN         0.0
# 3                      NaN         0.0
# 4                      NaN  76000000.0
# 5                      NaN         0.0
# ...                    ...         ...
# 2893                   NaN         0.0
# 2894                   NaN         0.0
# 2895                   NaN         0.0
# 2896                   NaN         0.0
# 2897                   NaN         0.0
#
#                                                  genres  \
# 1                                                    []
# 2     [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 3     [{'id': 9648, 'name': 'Mystery'}, {'id': 35, '...
# 4     [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 5     [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
# ...                                                 ...
# 2893                     [{'id': 35, 'name': 'Comedy'}]
# 2894                      [{'id': 18, 'name': 'Drama'}]
# 2895  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2896                      [{'id': 18, 'name': 'Drama'}]
# 2897  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
#
#                                                homepage        id  \
# 1                                                   NaN   30356.0
# 2                                                   NaN   58520.0
# 3                                                   NaN  459563.0
# 4     http://www.universalstudiosentertainment.com/c...    9693.0
# 5                                                   NaN    9925.0
# ...                                                 ...       ...
# 2893                                                NaN  490059.0
# 2894                                                NaN  566831.0
# 2895                                                NaN  108925.0
# 2896                                                NaN  874426.0
# 2897                                                NaN  922954.0
#
#      original_language                 original_title  \
# 1                   en  Whispers from a Shallow Grave
# 2                   en         Live Freaky Die Freaky
# 3                   en          Death of a Saleswoman
# 4                   en                Children of Men
# 5                   en                    Funny Money
# ...                ...                            ...
# 2893                ko                           도약선생
# 2894                ja                       お米とおっぱい。
# 2895                en              The Wrong Ferarri
# 2896                zh                    North point
# 2897                zh                           百年情书
#
#                                                overview  popularity  \
# 1     When a beautiful photo model disappears, polic...       1.176
# 2     It is the year 3069 and the Earth has been rob...       3.131
# 3     Top-ranking RubberTubber saleswoman Agatha J. ...       0.600
# 4     In 2027, in a chaotic world in which humans ca...      19.318
# 5     Henry Perkins, a mild-mannered accountant, acc...       5.591
# ...                                                 ...         ...
# 2893  Won-sik is kicked out by her roommate Woo-jung...       0.914
# 2894  What would you choose, between rice and boobs,...       1.400
# 2895  The Wrong Ferarri is a feature-film written an...       1.884
# 2896                                                NaN       1.343
# 2897                                                NaN       1.343
#
#                            poster_path  \
# 1     /cjRqAh3u2Z0MBx9GtT1k7Z9732w.jpg
# 2     /3QKPZ9SzMcBdqkKdSitQbmRqB2l.jpg
# 3     /tIfllOpkhZl5sbqZd1X77iiaJDj.jpg
# 4     /k9IAS4TehZFcKi4HVByxZNPfqex.jpg
# 5     /oG3jWUZiDqqrdk3oKwPEkuwoN89.jpg
# ...                                ...
# 2893  /rXrDkS3Mpow9q915zrmiH3stAn5.jpg
# 2894  /4cmlMKKDkbCxm2Kjs4gfmTFL7XE.jpg
# 2895                               NaN
# 2896  /ynnOmcXSIQlWnCykRWA3o0rPsAv.jpg
# 2897  /aeaGbLhM42ZpRyII6groNe4Hg5I.jpg
#
#                                    production_companies  \
# 1                                                    []
# 2                                                    []
# 3     [{'id': 90905, 'logo_path': None, 'name': 'Gir...
# 4     [{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKX...
# 5     [{'id': 110622, 'logo_path': None, 'name': 'FW...
# ...                                                 ...
# 2893                                                 []
# 2894  [{'id': 11725, 'logo_path': '/3OZxd70DZ1LbVelm...
# 2895                                                 []
# 2896  [{'id': 158558, 'logo_path': None, 'name': '上海...
# 2897                                                 []
#
#                                    production_countries release_date  \
# 1     [{'iso_3166_1': 'US', 'name': 'United States o...   1997-01-01
# 2     [{'iso_3166_1': 'US', 'name': 'United States o...   2006-01-31
# 3     [{'iso_3166_1': 'US', 'name': 'United States o...   2006-09-18
# 4     [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   2006-09-22
# 5     [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'is...   2006-01-01
# ...                                                 ...          ...
# 2893      [{'iso_3166_1': 'KR', 'name': 'South Korea'}]   2011-06-30
# 2894            [{'iso_3166_1': 'JP', 'name': 'Japan'}]   2011-07-01
# 2895  [{'iso_3166_1': 'US', 'name': 'United States o...   2011-04-04
# 2896                                                 []   2011-11-04
# 2897                                                 []   2011-05-13
#
#          revenue  runtime                                   spoken_languages  \
# 1            0.0     90.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2            0.0     75.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 3            0.0     77.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 4     70595464.0    109.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 5            0.0     98.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# ...          ...      ...                                                ...
# 2893         0.0     65.0  [{'english_name': 'Korean', 'iso_639_1': 'ko',...
# 2894         0.0    102.0  [{'english_name': 'Japanese', 'iso_639_1': 'ja...
# 2895         0.0     72.0                                                 []
# 2896         0.0      0.0                                                 []
# 2897         0.0      0.0  [{'english_name': 'Mandarin', 'iso_639_1': 'zh...
#
#         status                                            tagline  \
# 1     Released                                                NaN
# 2     Released                                                NaN
# 3     Released  6 housewives. 1 dead body. A trunk full of pla...
# 4     Released                  The future's a thing of the past.
# 5     Released  Henry Perkins accidentally trades briefcases w...
# ...        ...                                                ...
# 2893  Released                                                NaN
# 2894  Released                                                NaN
# 2895  Released                                                NaN
# 2896  Released                                                NaN
# 2897  Released                                                NaN
#
#                               title  video  vote_average  vote_count  \
# 1     Whispers from a Shallow Grave    0.0           2.0         2.0
# 2            Live Freaky Die Freaky    0.0           3.8         8.0
# 3             Death of a Saleswoman    0.0           3.0         1.0
# 4                   Children of Men    0.0           7.6      5779.0
# 5                       Funny Money    0.0           5.4        39.0
# ...                             ...    ...           ...         ...
# 2893                       Dr. Jump    0.0           7.0         1.0
# 2894                 Rice and Boobs    0.0           0.0         0.0
# 2895              The Wrong Ferarri    0.0           2.0         1.0
# 2896                    North point    0.0           0.0         0.0
# 2897                           百年情书    0.0           0.0         0.0
#
#      certification
# 1              NaN
# 2               NR
# 3              NaN
# 4                R
# 5                R
# ...            ...
# 2893           NaN
# 2894           NaN
# 2895           NaN
# 2896           NaN
# 2897           NaN
#
# [60130 rows x 26 columns]

# %%
## saving the combined csv to disk
df.to_csv('../Data/combined_all_data.csv.gz', compression="gzip", index = False)

# %% [markdown]
# # Preprocessing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60130 entries, 1 to 2897
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                60130 non-null  object
#  1   adult                  60130 non-null  float64
#  2   backdrop_path          36994 non-null  object
#  3   belongs_to_collection  3738 non-null   object
#  4   budget                 60130 non-null  float64
#  5   genres                 60130 non-null  object
#  6   homepage               14776 non-null  object
#  7   id                     60130 non-null  float64
#  8   original_language      60130 non-null  object
#  9   original_title         60130 non-null  object
#  10  overview               58761 non-null  object
#  11  popularity             60130 non-null  float64
#  12  poster_path            54382 non-null  object
#  13  production_companies   60130 non-null  object
#  14  production_countries   60130 non-null  object
#  15  release_date           59078 non-null  object
#  16  revenue                60130 non-null  float64
#  17  runtime                59298 non-null  float64
#  18  spoken_languages       60130 non-null  object
#  19  status                 60130 non-null  object
#  20  tagline                22079 non-null  object
#  21  title                  60130 non-null  object
#  22  video                  60130 non-null  float64
#  23  vote_average           60130 non-null  float64
#  24  vote_count             60130 non-null  float64
#  25  certification          14624 non-null  object
# dtypes: float64(9), object(17)
# memory usage: 12.4+ MB

# %%
## Columns to exclude
drop_cols = ['backdrop_path','backdrop_path','original_title','overview',
                 'poster_path','status','tagline','id','homepage',
                 'production_countries','video','production_companies','spoken_languages',
            'original_language']

## drop columns
df = df.drop(columns=drop_cols)
df
# Out:
#         imdb_id  adult belongs_to_collection      budget  \
# 1     tt0144280    0.0                   NaN    100000.0
# 2     tt0197633    0.0                   NaN         0.0
# 3     tt0204250    0.0                   NaN         0.0
# 4     tt0206634    0.0                   NaN  76000000.0
# 5     tt0244521    0.0                   NaN         0.0
# ...         ...    ...                   ...         ...
# 2893  tt9282946    0.0                   NaN         0.0
# 2894  tt9385434    0.0                   NaN         0.0
# 2895  tt9452878    0.0                   NaN         0.0
# 2896  tt9519786    0.0                   NaN         0.0
# 2897  tt9547900    0.0                   NaN         0.0
#
#                                                  genres  popularity  \
# 1                                                    []       1.176
# 2     [{'id': 16, 'name': 'Animation'}, {'id': 35, '...       3.131
# 3     [{'id': 9648, 'name': 'Mystery'}, {'id': 35, '...       0.600
# 4     [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      19.318
# 5     [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...       5.591
# ...                                                 ...         ...
# 2893                     [{'id': 35, 'name': 'Comedy'}]       0.914
# 2894                      [{'id': 18, 'name': 'Drama'}]       1.400
# 2895  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...       1.884
# 2896                      [{'id': 18, 'name': 'Drama'}]       1.343
# 2897  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...       1.343
#
#      release_date     revenue  runtime                          title  \
# 1      1997-01-01         0.0     90.0  Whispers from a Shallow Grave
# 2      2006-01-31         0.0     75.0         Live Freaky Die Freaky
# 3      2006-09-18         0.0     77.0          Death of a Saleswoman
# 4      2006-09-22  70595464.0    109.0                Children of Men
# 5      2006-01-01         0.0     98.0                    Funny Money
# ...           ...         ...      ...                            ...
# 2893   2011-06-30         0.0     65.0                       Dr. Jump
# 2894   2011-07-01         0.0    102.0                 Rice and Boobs
# 2895   2011-04-04         0.0     72.0              The Wrong Ferarri
# 2896   2011-11-04         0.0      0.0                    North point
# 2897   2011-05-13         0.0      0.0                           百年情书
#
#       vote_average  vote_count certification
# 1              2.0         2.0           NaN
# 2              3.8         8.0            NR
# 3              3.0         1.0           NaN
# 4              7.6      5779.0             R
# 5              5.4        39.0             R
# ...            ...         ...           ...
# 2893           7.0         1.0           NaN
# 2894           0.0         0.0           NaN
# 2895           2.0         1.0           NaN
# 2896           0.0         0.0           NaN
# 2897           0.0         0.0           NaN
#
# [60130 rows x 13 columns]

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# - belongs to collection: convert to boolean
# - Genres: get just name and manually OHE
# - Cleaning Categories in Certification
# - Converting release date to year, month, and day.

# %% [markdown]
# ### belongs to collection

# %%
df['belongs_to_collection'].value_counts()
# Out:
# {'id': 39199, 'name': 'Detective Conan Collection', 'poster_path': '/1wBfr532NOQK68wlo5ApjCmiQIB.jpg', 'backdrop_path': '/9bogrpii4e61SR6a9qLHow7I46U.jpg'}               18
# {'id': 148065, 'name': 'Doraemon Collection', 'poster_path': '/4TLSP1KD1uAlp2q1rTrc6SFlktX.jpg', 'backdrop_path': '/rc6OFcSasL5YxBRPUQVwxmVF6h5.jpg'}                     16
# {'id': 403643, 'name': 'Troublesome Night Collection', 'poster_path': '/bPTx3TP4UJTHQfcLx4qIub9LXmi.jpg', 'backdrop_path': '/n3a7zF5GuxM2X8oPF6pKXqYS6ER.jpg'}            15
# {'id': 23456, 'name': 'One Piece Collection', 'poster_path': '/nvAPotUDNcKStSOv2ojGZBNOX8A.jpg', 'backdrop_path': '/3RqSKjokWlXyTBUt3tcR9CrOG57.jpg'}                     13
# {'id': 23616, 'name': 'Naruto Collection', 'poster_path': '/q9rrfRgPUFkFqDF74jlvNYp3RpN.jpg', 'backdrop_path': '/prLI2SNNkd9wcQkFh9iWXzQtR5D.jpg'}                        11
#                                                                                                                                                                           ..
# {'id': 741633, 'name': 'Twittering Birds Never Fly  Collection', 'poster_path': None, 'backdrop_path': None}                                                               1
# {'id': 730695, 'name': 'Class Reunion Collection', 'poster_path': '/j4u91TNk7k0LDgjwAjg0lnRgFe9.jpg', 'backdrop_path': '/b9WaDpvFtNaW96e1S5ru4yoZce2.jpg'}                 1
# {'id': 946322, 'name': 'Lethal Kittens Collection', 'poster_path': None, 'backdrop_path': None}                                                                            1
# {'id': 486690, 'name': 'Inmu', 'poster_path': '/tk4Ve4sM6NyupOCYSFl8vcHU0EC.jpg', 'backdrop_path': None}                                                                   1
# {'id': 190435, 'name': 'Street Fighter (Animated) Collection', 'poster_path': '/zrX0hsl3ny8WWCe5ww5PZlHgjjc.jpg', 'backdrop_path': '/kkUdnFLEwzHPU8medJE2Vn4pm1B.jpg'}     1
# Name: belongs_to_collection, Length: 1867, dtype: int64

# %%
# there are 3,700+ movies that belong to collections
df['belongs_to_collection'] = df['belongs_to_collection'].notna()
df['belongs_to_collection'].value_counts(dropna=False)
# Out:
# False    56392
# True      3738
# Name: belongs_to_collection, dtype: int64

# %% [markdown]
# ### genre

# %%
df.reset_index(inplace=True)

# %%
df.loc[3,'genres']
# Out:
# "[{'id': 18, 'name': 'Drama'}, {'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}, {'id': 878, 'name': 'Science Fiction'}]"

# %%
## Function to get just the genre names as a list 
import json
def get_genre_name(x):
    x = x.replace("'",'"')
    x = json.loads(x)
    
    genres = []
    for genre in x:
        genres.append(genre['name'])
    return genres

# %%
## Use our function #and exploding the new column
df['genre_list'] = df['genres'].apply(get_genre_name)
df
# Out:
#        index    imdb_id  adult  belongs_to_collection      budget  \
# 0          1  tt0144280    0.0                  False    100000.0
# 1          2  tt0197633    0.0                  False         0.0
# 2          3  tt0204250    0.0                  False         0.0
# 3          4  tt0206634    0.0                  False  76000000.0
# 4          5  tt0244521    0.0                  False         0.0
# ...      ...        ...    ...                    ...         ...
# 60125   2893  tt9282946    0.0                  False         0.0
# 60126   2894  tt9385434    0.0                  False         0.0
# 60127   2895  tt9452878    0.0                  False         0.0
# 60128   2896  tt9519786    0.0                  False         0.0
# 60129   2897  tt9547900    0.0                  False         0.0
#
#                                                   genres  popularity  \
# 0                                                     []       1.176
# 1      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...       3.131
# 2      [{'id': 9648, 'name': 'Mystery'}, {'id': 35, '...       0.600
# 3      [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      19.318
# 4      [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...       5.591
# ...                                                  ...         ...
# 60125                     [{'id': 35, 'name': 'Comedy'}]       0.914
# 60126                      [{'id': 18, 'name': 'Drama'}]       1.400
# 60127  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...       1.884
# 60128                      [{'id': 18, 'name': 'Drama'}]       1.343
# 60129  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...       1.343
#
#       release_date     revenue  runtime                          title  \
# 0       1997-01-01         0.0     90.0  Whispers from a Shallow Grave
# 1       2006-01-31         0.0     75.0         Live Freaky Die Freaky
# 2       2006-09-18         0.0     77.0          Death of a Saleswoman
# 3       2006-09-22  70595464.0    109.0                Children of Men
# 4       2006-01-01         0.0     98.0                    Funny Money
# ...            ...         ...      ...                            ...
# 60125   2011-06-30         0.0     65.0                       Dr. Jump
# 60126   2011-07-01         0.0    102.0                 Rice and Boobs
# 60127   2011-04-04         0.0     72.0              The Wrong Ferarri
# 60128   2011-11-04         0.0      0.0                    North point
# 60129   2011-05-13         0.0      0.0                           百年情书
#
#        vote_average  vote_count certification  \
# 0               2.0         2.0           NaN
# 1               3.8         8.0            NR
# 2               3.0         1.0           NaN
# 3               7.6      5779.0             R
# 4               5.4        39.0             R
# ...             ...         ...           ...
# 60125           7.0         1.0           NaN
# 60126           0.0         0.0           NaN
# 60127           2.0         1.0           NaN
# 60128           0.0         0.0           NaN
# 60129           0.0         0.0           NaN
#
#                                         genre_list
# 0                                               []
# 1      [Animation, Comedy, Music, Science Fiction]
# 2                                [Mystery, Comedy]
# 3       [Drama, Action, Thriller, Science Fiction]
# 4                                  [Comedy, Crime]
# ...                                            ...
# 60125                                     [Comedy]
# 60126                                      [Drama]
# 60127                       [Comedy, Drama, Music]
# 60128                                      [Drama]
# 60129                             [Drama, History]
#
# [60130 rows x 15 columns]

# %%
df_explode = df.explode('genre_list')
df_explode
# Out:
#        index    imdb_id  adult  belongs_to_collection    budget  \
# 0          1  tt0144280    0.0                  False  100000.0
# 1          2  tt0197633    0.0                  False       0.0
# 1          2  tt0197633    0.0                  False       0.0
# 1          2  tt0197633    0.0                  False       0.0
# 1          2  tt0197633    0.0                  False       0.0
# ...      ...        ...    ...                    ...       ...
# 60127   2895  tt9452878    0.0                  False       0.0
# 60127   2895  tt9452878    0.0                  False       0.0
# 60128   2896  tt9519786    0.0                  False       0.0
# 60129   2897  tt9547900    0.0                  False       0.0
# 60129   2897  tt9547900    0.0                  False       0.0
#
#                                                   genres  popularity  \
# 0                                                     []       1.176
# 1      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...       3.131
# 1      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...       3.131
# 1      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...       3.131
# 1      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...       3.131
# ...                                                  ...         ...
# 60127  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...       1.884
# 60127  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...       1.884
# 60128                      [{'id': 18, 'name': 'Drama'}]       1.343
# 60129  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...       1.343
# 60129  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...       1.343
#
#       release_date  revenue  runtime                          title  \
# 0       1997-01-01      0.0     90.0  Whispers from a Shallow Grave
# 1       2006-01-31      0.0     75.0         Live Freaky Die Freaky
# 1       2006-01-31      0.0     75.0         Live Freaky Die Freaky
# 1       2006-01-31      0.0     75.0         Live Freaky Die Freaky
# 1       2006-01-31      0.0     75.0         Live Freaky Die Freaky
# ...            ...      ...      ...                            ...
# 60127   2011-04-04      0.0     72.0              The Wrong Ferarri
# 60127   2011-04-04      0.0     72.0              The Wrong Ferarri
# 60128   2011-11-04      0.0      0.0                    North point
# 60129   2011-05-13      0.0      0.0                           百年情书
# 60129   2011-05-13      0.0      0.0                           百年情书
#
#        vote_average  vote_count certification       genre_list
# 0               2.0         2.0           NaN              NaN
# 1               3.8         8.0            NR        Animation
# 1               3.8         8.0            NR           Comedy
# 1               3.8         8.0            NR            Music
# 1               3.8         8.0            NR  Science Fiction
# ...             ...         ...           ...              ...
# 60127           2.0         1.0           NaN            Drama
# 60127           2.0         1.0           NaN            Music
# 60128           0.0         0.0           NaN            Drama
# 60129           0.0         0.0           NaN            Drama
# 60129           0.0         0.0           NaN          History
#
# [111511 rows x 15 columns]

# %%
## save unique genres
unique_genres = df_explode['genre_list'].dropna().unique()
unique_genres
# Out:
# array(['Animation', 'Comedy', 'Music', 'Science Fiction', 'Mystery',
#        'Drama', 'Action', 'Thriller', 'Crime', 'Romance', 'Horror',
#        'Adventure', 'Family', 'Fantasy', 'History', 'Documentary', 'War',
#        'Western', 'TV Movie'], dtype=object)

# %%
## Manually One-Hot-Encode Genres
for genre in unique_genres:
    df[f"Genre_{genre}"] = df['genres'].str.contains(genre,regex=False)    
df
# Out:
#        index    imdb_id  adult  belongs_to_collection      budget  \
# 0          1  tt0144280    0.0                  False    100000.0
# 1          2  tt0197633    0.0                  False         0.0
# 2          3  tt0204250    0.0                  False         0.0
# 3          4  tt0206634    0.0                  False  76000000.0
# 4          5  tt0244521    0.0                  False         0.0
# ...      ...        ...    ...                    ...         ...
# 60125   2893  tt9282946    0.0                  False         0.0
# 60126   2894  tt9385434    0.0                  False         0.0
# 60127   2895  tt9452878    0.0                  False         0.0
# 60128   2896  tt9519786    0.0                  False         0.0
# 60129   2897  tt9547900    0.0                  False         0.0
#
#                                                   genres  popularity  \
# 0                                                     []       1.176
# 1      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...       3.131
# 2      [{'id': 9648, 'name': 'Mystery'}, {'id': 35, '...       0.600
# 3      [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      19.318
# 4      [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...       5.591
# ...                                                  ...         ...
# 60125                     [{'id': 35, 'name': 'Comedy'}]       0.914
# 60126                      [{'id': 18, 'name': 'Drama'}]       1.400
# 60127  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...       1.884
# 60128                      [{'id': 18, 'name': 'Drama'}]       1.343
# 60129  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...       1.343
#
#       release_date     revenue  runtime                          title  \
# 0       1997-01-01         0.0     90.0  Whispers from a Shallow Grave
# 1       2006-01-31         0.0     75.0         Live Freaky Die Freaky
# 2       2006-09-18         0.0     77.0          Death of a Saleswoman
# 3       2006-09-22  70595464.0    109.0                Children of Men
# 4       2006-01-01         0.0     98.0                    Funny Money
# ...            ...         ...      ...                            ...
# 60125   2011-06-30         0.0     65.0                       Dr. Jump
# 60126   2011-07-01         0.0    102.0                 Rice and Boobs
# 60127   2011-04-04         0.0     72.0              The Wrong Ferarri
# 60128   2011-11-04         0.0      0.0                    North point
# 60129   2011-05-13         0.0      0.0                           百年情书
#
#        vote_average  vote_count certification  \
# 0               2.0         2.0           NaN
# 1               3.8         8.0            NR
# 2               3.0         1.0           NaN
# 3               7.6      5779.0             R
# 4               5.4        39.0             R
# ...             ...         ...           ...
# 60125           7.0         1.0           NaN
# 60126           0.0         0.0           NaN
# 60127           2.0         1.0           NaN
# 60128           0.0         0.0           NaN
# 60129           0.0         0.0           NaN
#
#                                         genre_list  Genre_Animation  \
# 0                                               []            False
# 1      [Animation, Comedy, Music, Science Fiction]             True
# 2                                [Mystery, Comedy]            False
# 3       [Drama, Action, Thriller, Science Fiction]            False
# 4                                  [Comedy, Crime]            False
# ...                                            ...              ...
# 60125                                     [Comedy]            False
# 60126                                      [Drama]            False
# 60127                       [Comedy, Drama, Music]            False
# 60128                                      [Drama]            False
# 60129                             [Drama, History]            False
#
#        Genre_Comedy  Genre_Music  Genre_Science Fiction  Genre_Mystery  \
# 0             False        False                  False          False
# 1              True         True                   True          False
# 2              True        False                  False           True
# 3             False        False                   True          False
# 4              True        False                  False          False
# ...             ...          ...                    ...            ...
# 60125          True        False                  False          False
# 60126         False        False                  False          False
# 60127          True         True                  False          False
# 60128         False        False                  False          False
# 60129         False        False                  False          False
#
#        Genre_Drama  Genre_Action  Genre_Thriller  Genre_Crime  Genre_Romance  \
# 0            False         False           False        False          False
# 1            False         False           False        False          False
# 2            False         False           False        False          False
# 3             True          True            True        False          False
# 4            False         False           False         True          False
# ...            ...           ...             ...          ...            ...
# 60125        False         False           False        False          False
# 60126         True         False           False        False          False
# 60127         True         False           False        False          False
# 60128         True         False           False        False          False
# 60129         True         False           False        False          False
#
#        Genre_Horror  Genre_Adventure  Genre_Family  Genre_Fantasy  \
# 0             False            False         False          False
# 1             False            False         False          False
# 2             False            False         False          False
# 3             False            False         False          False
# 4             False            False         False          False
# ...             ...              ...           ...            ...
# 60125         False            False         False          False
# 60126         False            False         False          False
# 60127         False            False         False          False
# 60128         False            False         False          False
# 60129         False            False         False          False
#
#        Genre_History  Genre_Documentary  Genre_War  Genre_Western  \
# 0              False              False      False          False
# 1              False              False      False          False
# 2              False              False      False          False
# 3              False              False      False          False
# 4              False              False      False          False
# ...              ...                ...        ...            ...
# 60125          False              False      False          False
# 60126          False              False      False          False
# 60127          False              False      False          False
# 60128          False              False      False          False
# 60129           True              False      False          False
#
#        Genre_TV Movie
# 0               False
# 1               False
# 2               False
# 3               False
# 4               False
# ...               ...
# 60125           False
# 60126           False
# 60127           False
# 60128           False
# 60129           False
#
# [60130 rows x 34 columns]

# %%
## Drop original genre cols
df = df.drop(columns=['genres','genre_list','index'])
df
# Out:
#          imdb_id  adult  belongs_to_collection      budget  popularity  \
# 0      tt0144280    0.0                  False    100000.0       1.176
# 1      tt0197633    0.0                  False         0.0       3.131
# 2      tt0204250    0.0                  False         0.0       0.600
# 3      tt0206634    0.0                  False  76000000.0      19.318
# 4      tt0244521    0.0                  False         0.0       5.591
# ...          ...    ...                    ...         ...         ...
# 60125  tt9282946    0.0                  False         0.0       0.914
# 60126  tt9385434    0.0                  False         0.0       1.400
# 60127  tt9452878    0.0                  False         0.0       1.884
# 60128  tt9519786    0.0                  False         0.0       1.343
# 60129  tt9547900    0.0                  False         0.0       1.343
#
#       release_date     revenue  runtime                          title  \
# 0       1997-01-01         0.0     90.0  Whispers from a Shallow Grave
# 1       2006-01-31         0.0     75.0         Live Freaky Die Freaky
# 2       2006-09-18         0.0     77.0          Death of a Saleswoman
# 3       2006-09-22  70595464.0    109.0                Children of Men
# 4       2006-01-01         0.0     98.0                    Funny Money
# ...            ...         ...      ...                            ...
# 60125   2011-06-30         0.0     65.0                       Dr. Jump
# 60126   2011-07-01         0.0    102.0                 Rice and Boobs
# 60127   2011-04-04         0.0     72.0              The Wrong Ferarri
# 60128   2011-11-04         0.0      0.0                    North point
# 60129   2011-05-13         0.0      0.0                           百年情书
#
#        vote_average  vote_count certification  Genre_Animation  Genre_Comedy  \
# 0               2.0         2.0           NaN            False         False
# 1               3.8         8.0            NR             True          True
# 2               3.0         1.0           NaN            False          True
# 3               7.6      5779.0             R            False         False
# 4               5.4        39.0             R            False          True
# ...             ...         ...           ...              ...           ...
# 60125           7.0         1.0           NaN            False          True
# 60126           0.0         0.0           NaN            False         False
# 60127           2.0         1.0           NaN            False          True
# 60128           0.0         0.0           NaN            False         False
# 60129           0.0         0.0           NaN            False         False
#
#        Genre_Music  Genre_Science Fiction  Genre_Mystery  Genre_Drama  \
# 0            False                  False          False        False
# 1             True                   True          False        False
# 2            False                  False           True        False
# 3            False                   True          False         True
# 4            False                  False          False        False
# ...            ...                    ...            ...          ...
# 60125        False                  False          False        False
# 60126        False                  False          False         True
# 60127         True                  False          False         True
# 60128        False                  False          False         True
# 60129        False                  False          False         True
#
#        Genre_Action  Genre_Thriller  Genre_Crime  Genre_Romance  Genre_Horror  \
# 0             False           False        False          False         False
# 1             False           False        False          False         False
# 2             False           False        False          False         False
# 3              True            True        False          False         False
# 4             False           False         True          False         False
# ...             ...             ...          ...            ...           ...
# 60125         False           False        False          False         False
# 60126         False           False        False          False         False
# 60127         False           False        False          False         False
# 60128         False           False        False          False         False
# 60129         False           False        False          False         False
#
#        Genre_Adventure  Genre_Family  Genre_Fantasy  Genre_History  \
# 0                False         False          False          False
# 1                False         False          False          False
# 2                False         False          False          False
# 3                False         False          False          False
# 4                False         False          False          False
# ...                ...           ...            ...            ...
# 60125            False         False          False          False
# 60126            False         False          False          False
# 60127            False         False          False          False
# 60128            False         False          False          False
# 60129            False         False          False           True
#
#        Genre_Documentary  Genre_War  Genre_Western  Genre_TV Movie
# 0                  False      False          False           False
# 1                  False      False          False           False
# 2                  False      False          False           False
# 3                  False      False          False           False
# 4                  False      False          False           False
# ...                  ...        ...            ...             ...
# 60125              False      False          False           False
# 60126              False      False          False           False
# 60127              False      False          False           False
# 60128              False      False          False           False
# 60129              False      False          False           False
#
# [60130 rows x 31 columns]

# %% [markdown]
# ### certification

# %%
## Checking Certification values
df['certification'].value_counts(dropna=False)
# Out:
# NaN                                45506
# R                                   6097
# NR                                  3261
# PG-13                               3224
# PG                                  1432
# G                                    442
# NC-17                                156
# Unrated                                5
# ScreamFest Horror Film Festival        1
# UR                                     1
# Not Rated                              1
# -                                      1
# PG-13                                  1
# 10                                     1
# R                                      1
# Name: certification, dtype: int64

# %%
# fix extra space certs
df['certification'] = df['certification'].str.strip()
df['certification'].value_counts(dropna=False)
# Out:
# NaN                                45506
# R                                   6098
# NR                                  3261
# PG-13                               3225
# PG                                  1432
# G                                    442
# NC-17                                156
# Unrated                                5
# ScreamFest Horror Film Festival        1
# UR                                     1
# Not Rated                              1
# -                                      1
# 10                                     1
# Name: certification, dtype: int64

# %%
## fix certification col
repl_cert = {'UR':'NR',
             'Not Rated':'NR',
             'Unrated':'NR',
             '-':'NR',
             '10':np.nan,
             'ScreamFest Horror Film Festival':'NR'}
df['certification'] = df['certification'].replace(repl_cert)#

df['certification'].value_counts()
# Out:
# R        6098
# NR       3270
# PG-13    3225
# PG       1432
# G         442
# NC-17     156
# Name: certification, dtype: int64

# %% [markdown]
# ### Converting year to sep features

# %%
## split release date into 3 columns
new_cols = ['year','month','day']
df[new_cols] = df['release_date'].str.split('-',expand=True)
df[new_cols] = df[new_cols].astype(float)
df
# Out:
#          imdb_id  adult  belongs_to_collection      budget  popularity  \
# 0      tt0144280    0.0                  False    100000.0       1.176
# 1      tt0197633    0.0                  False         0.0       3.131
# 2      tt0204250    0.0                  False         0.0       0.600
# 3      tt0206634    0.0                  False  76000000.0      19.318
# 4      tt0244521    0.0                  False         0.0       5.591
# ...          ...    ...                    ...         ...         ...
# 60125  tt9282946    0.0                  False         0.0       0.914
# 60126  tt9385434    0.0                  False         0.0       1.400
# 60127  tt9452878    0.0                  False         0.0       1.884
# 60128  tt9519786    0.0                  False         0.0       1.343
# 60129  tt9547900    0.0                  False         0.0       1.343
#
#       release_date     revenue  runtime                          title  \
# 0       1997-01-01         0.0     90.0  Whispers from a Shallow Grave
# 1       2006-01-31         0.0     75.0         Live Freaky Die Freaky
# 2       2006-09-18         0.0     77.0          Death of a Saleswoman
# 3       2006-09-22  70595464.0    109.0                Children of Men
# 4       2006-01-01         0.0     98.0                    Funny Money
# ...            ...         ...      ...                            ...
# 60125   2011-06-30         0.0     65.0                       Dr. Jump
# 60126   2011-07-01         0.0    102.0                 Rice and Boobs
# 60127   2011-04-04         0.0     72.0              The Wrong Ferarri
# 60128   2011-11-04         0.0      0.0                    North point
# 60129   2011-05-13         0.0      0.0                           百年情书
#
#        vote_average  vote_count certification  Genre_Animation  Genre_Comedy  \
# 0               2.0         2.0           NaN            False         False
# 1               3.8         8.0            NR             True          True
# 2               3.0         1.0           NaN            False          True
# 3               7.6      5779.0             R            False         False
# 4               5.4        39.0             R            False          True
# ...             ...         ...           ...              ...           ...
# 60125           7.0         1.0           NaN            False          True
# 60126           0.0         0.0           NaN            False         False
# 60127           2.0         1.0           NaN            False          True
# 60128           0.0         0.0           NaN            False         False
# 60129           0.0         0.0           NaN            False         False
#
#        Genre_Music  Genre_Science Fiction  Genre_Mystery  Genre_Drama  \
# 0            False                  False          False        False
# 1             True                   True          False        False
# 2            False                  False           True        False
# 3            False                   True          False         True
# 4            False                  False          False        False
# ...            ...                    ...            ...          ...
# 60125        False                  False          False        False
# 60126        False                  False          False         True
# 60127         True                  False          False         True
# 60128        False                  False          False         True
# 60129        False                  False          False         True
#
#        Genre_Action  Genre_Thriller  Genre_Crime  Genre_Romance  Genre_Horror  \
# 0             False           False        False          False         False
# 1             False           False        False          False         False
# 2             False           False        False          False         False
# 3              True            True        False          False         False
# 4             False           False         True          False         False
# ...             ...             ...          ...            ...           ...
# 60125         False           False        False          False         False
# 60126         False           False        False          False         False
# 60127         False           False        False          False         False
# 60128         False           False        False          False         False
# 60129         False           False        False          False         False
#
#        Genre_Adventure  Genre_Family  Genre_Fantasy  Genre_History  \
# 0                False         False          False          False
# 1                False         False          False          False
# 2                False         False          False          False
# 3                False         False          False          False
# 4                False         False          False          False
# ...                ...           ...            ...            ...
# 60125            False         False          False          False
# 60126            False         False          False          False
# 60127            False         False          False          False
# 60128            False         False          False          False
# 60129            False         False          False           True
#
#        Genre_Documentary  Genre_War  Genre_Western  Genre_TV Movie    year  \
# 0                  False      False          False           False  1997.0
# 1                  False      False          False           False  2006.0
# 2                  False      False          False           False  2006.0
# 3                  False      False          False           False  2006.0
# 4                  False      False          False           False  2006.0
# ...                  ...        ...            ...             ...     ...
# 60125              False      False          False           False  2011.0
# 60126              False      False          False           False  2011.0
# 60127              False      False          False           False  2011.0
# 60128              False      False          False           False  2011.0
# 60129              False      False          False           False  2011.0
#
#        month   day
# 0        1.0   1.0
# 1        1.0  31.0
# 2        9.0  18.0
# 3        9.0  22.0
# 4        1.0   1.0
# ...      ...   ...
# 60125    6.0  30.0
# 60126    7.0   1.0
# 60127    4.0   4.0
# 60128   11.0   4.0
# 60129    5.0  13.0
#
# [60130 rows x 34 columns]

# %%
## drop original feature
df = df.drop(columns=['release_date'])

# %% [markdown]
# ## Train Test Split

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60130 entries, 0 to 60129
# Data columns (total 33 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                60130 non-null  object
#  1   adult                  60130 non-null  float64
#  2   belongs_to_collection  60130 non-null  bool
#  3   budget                 60130 non-null  float64
#  4   popularity             60130 non-null  float64
#  5   revenue                60130 non-null  float64
#  6   runtime                59298 non-null  float64
#  7   title                  60130 non-null  object
#  8   vote_average           60130 non-null  float64
#  9   vote_count             60130 non-null  float64
#  10  certification          14623 non-null  object
#  11  Genre_Animation        60130 non-null  bool
#  12  Genre_Comedy           60130 non-null  bool
#  13  Genre_Music            60130 non-null  bool
#  14  Genre_Science Fiction  60130 non-null  bool
#  15  Genre_Mystery          60130 non-null  bool
#  16  Genre_Drama            60130 non-null  bool
#  17  Genre_Action           60130 non-null  bool
#  18  Genre_Thriller         60130 non-null  bool
#  19  Genre_Crime            60130 non-null  bool
#  20  Genre_Romance          60130 non-null  bool
#  21  Genre_Horror           60130 non-null  bool
#  22  Genre_Adventure        60130 non-null  bool
#  23  Genre_Family           60130 non-null  bool
#  24  Genre_Fantasy          60130 non-null  bool
#  25  Genre_History          60130 non-null  bool
#  26  Genre_Documentary      60130 non-null  bool
#  27  Genre_War              60130 non-null  bool
#  28  Genre_Western          60130 non-null  bool
#  29  Genre_TV Movie         60130 non-null  bool
#  30  year                   59078 non-null  float64
#  31  month                  59078 non-null  float64
#  32  day                    59078 non-null  float64
# dtypes: bool(20), float64(10), object(3)
# memory usage: 7.1+ MB

# %%
## Make x and y variables
drop_for_model = ['title','imdb_id']

y = df['revenue'].copy()
X = df.drop(columns=['revenue',*drop_for_model]).copy()

X_train, X_test, y_train, y_test = train_test_split(X,y)#, random_state=321)
X_train.head()
# Out:
#        adult  belongs_to_collection  budget  popularity  runtime  \
# 9538     0.0                  False     0.0       0.600     70.0
# 16553    0.0                  False     0.0       9.087    100.0
# 34106    0.0                  False    10.0       1.842     89.0
# 3804     0.0                  False     0.0       1.092     97.0
# 37747    0.0                  False     0.0       1.209     98.0
#
#        vote_average  vote_count certification  Genre_Animation  Genre_Comedy  \
# 9538            0.0         0.0           NaN            False         False
# 16553           6.1       141.0           NaN            False          True
# 34106           4.5         4.0           NaN            False         False
# 3804            0.0         0.0           NaN            False         False
# 37747           2.8         8.0           NaN            False          True
#
#        Genre_Music  Genre_Science Fiction  Genre_Mystery  Genre_Drama  \
# 9538         False                  False          False        False
# 16553        False                  False          False        False
# 34106        False                  False          False        False
# 3804         False                  False          False         True
# 37747        False                  False          False        False
#
#        Genre_Action  Genre_Thriller  Genre_Crime  Genre_Romance  Genre_Horror  \
# 9538          False           False        False          False         False
# 16553         False           False        False           True         False
# 34106         False           False        False          False          True
# 3804          False           False        False          False         False
# 37747         False           False        False          False         False
#
#        Genre_Adventure  Genre_Family  Genre_Fantasy  Genre_History  \
# 9538             False         False          False          False
# 16553            False         False          False          False
# 34106            False         False          False          False
# 3804             False         False          False          False
# 37747            False         False          False          False
#
#        Genre_Documentary  Genre_War  Genre_Western  Genre_TV Movie    year  \
# 9538               False      False          False           False  2007.0
# 16553              False      False          False           False  2018.0
# 34106              False      False          False           False  2012.0
# 3804               False      False          False           False  2008.0
# 37747              False      False          False           False  2019.0
#
#        month   day
# 9538    10.0  24.0
# 16553   12.0   7.0
# 34106    3.0  18.0
# 3804     8.0   7.0
# 37747    7.0  12.0

# %%
X_train.isna().sum()
# Out:
# adult                        0
# belongs_to_collection        0
# budget                       0
# popularity                   0
# runtime                    626
# vote_average                 0
# vote_count                   0
# certification            34093
# Genre_Animation              0
# Genre_Comedy                 0
# Genre_Music                  0
# Genre_Science Fiction        0
# Genre_Mystery                0
# Genre_Drama                  0
# Genre_Action                 0
# Genre_Thriller               0
# Genre_Crime                  0
# Genre_Romance                0
# Genre_Horror                 0
# Genre_Adventure              0
# Genre_Family                 0
# Genre_Fantasy                0
# Genre_History                0
# Genre_Documentary            0
# Genre_War                    0
# Genre_Western                0
# Genre_TV Movie               0
# year                       760
# month                      760
# day                        760
# dtype: int64

# %%
## make cat selector and using it to save list of column names
cat_select = make_column_selector(dtype_include='object')
cat_cols = cat_select(X_train)
cat_cols
# Out:
# ['certification']

# %%
## select manually OHE cols for later
bool_select = make_column_selector(dtype_include='bool')
already_ohe_cols = bool_select(X_train)
already_ohe_cols
# Out:
# ['belongs_to_collection',
#  'Genre_Animation',
#  'Genre_Comedy',
#  'Genre_Music',
#  'Genre_Science Fiction',
#  'Genre_Mystery',
#  'Genre_Drama',
#  'Genre_Action',
#  'Genre_Thriller',
#  'Genre_Crime',
#  'Genre_Romance',
#  'Genre_Horror',
#  'Genre_Adventure',
#  'Genre_Family',
#  'Genre_Fantasy',
#  'Genre_History',
#  'Genre_Documentary',
#  'Genre_War',
#  'Genre_Western',
#  'Genre_TV Movie']

# %%
## make num selector and using it to save list of column names
num_select = make_column_selector(dtype_include='number')
num_cols = num_select(X_train)
num_cols
# Out:
# ['adult',
#  'budget',
#  'popularity',
#  'runtime',
#  'vote_average',
#  'vote_count',
#  'year',
#  'month',
#  'day']

# %%
## convert manual ohe to int
X_train[already_ohe_cols] = X_train[already_ohe_cols].astype(int)
X_test[already_ohe_cols] = X_test[already_ohe_cols].astype(int)

# %%
## make pipelines
cat_pipe = make_pipeline(SimpleImputer(strategy='constant',
                                       fill_value='MISSING'),
                         OneHotEncoder(handle_unknown='ignore', sparse=False))
num_pipe = make_pipeline(SimpleImputer(strategy='mean'),#StandardScaler()
                        )

preprocessor = make_column_transformer((cat_pipe,cat_cols),
                                        (num_pipe, num_cols),
                                       ('passthrough',already_ohe_cols))# remainder='passthrough')
preprocessor
# Out:
# ColumnTransformer(transformers=[('pipeline-1',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(fill_value='MISSING',
#                                                                 strategy='constant')),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False))]),
#                                  ['certification']),
#                                 ('pipeline-2',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer())]),
#                                  ['adult', 'budget', 'popularity', 'runtime',
#                                   'vote_average', '...
#                                 ('passthrough', 'passthrough',
#                                  ['belongs_to_collection', 'Genre_Animation',
#                                   'Genre_Comedy', 'Genre_Music',
#                                   'Genre_Science Fiction', 'Genre_Mystery',
#                                   'Genre_Drama', 'Genre_Action',
#                                   'Genre_Thriller', 'Genre_Crime',
#                                   'Genre_Romance', 'Genre_Horror',
#                                   'Genre_Adventure', 'Genre_Family',
#                                   'Genre_Fantasy', 'Genre_History',
#                                   'Genre_Documentary', 'Genre_War',
#                                   'Genre_Western', 'Genre_TV Movie'])])

# %%
## fit the col transformer
preprocessor.fit(X_train)
# Out:
# ColumnTransformer(transformers=[('pipeline-1',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(fill_value='MISSING',
#                                                                 strategy='constant')),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False))]),
#                                  ['certification']),
#                                 ('pipeline-2',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer())]),
#                                  ['adult', 'budget', 'popularity', 'runtime',
#                                   'vote_average', '...
#                                 ('passthrough', 'passthrough',
#                                  ['belongs_to_collection', 'Genre_Animation',
#                                   'Genre_Comedy', 'Genre_Music',
#                                   'Genre_Science Fiction', 'Genre_Mystery',
#                                   'Genre_Drama', 'Genre_Action',
#                                   'Genre_Thriller', 'Genre_Crime',
#                                   'Genre_Romance', 'Genre_Horror',
#                                   'Genre_Adventure', 'Genre_Family',
#                                   'Genre_Fantasy', 'Genre_History',
#                                   'Genre_Documentary', 'Genre_War',
#                                   'Genre_Western', 'Genre_TV Movie'])])

# %%
## Finding the categorical pipeline in our col transformer.
preprocessor.named_transformers_['pipeline-1'][-1]
# Out:
# OneHotEncoder(handle_unknown='ignore', sparse=False)

# %%
## B) Using list-slicing to find the encoder 
cat_features = preprocessor.named_transformers_['pipeline-1'][-1].get_feature_names_out(cat_cols)
cat_features
# Out:
# array(['certification_G', 'certification_MISSING', 'certification_NC-17',
#        'certification_NR', 'certification_PG', 'certification_PG-13',
#        'certification_R'], dtype=object)

# %%
## Create the empty list
final_features = [*cat_features,*num_cols,*already_ohe_cols]
len(final_features)
# Out:
# 36

# %%
## checking shape matches len final features
preprocessor.transform(X_train).shape
# Out:
# (45097, 36)

# %%
## make X_train_tf 
X_train_tf = pd.DataFrame( preprocessor.transform(X_train), 
                          columns=final_features, index=X_train.index)
X_train_tf.head()
# Out:
#        certification_G  certification_MISSING  certification_NC-17  \
# 9538               0.0                    1.0                  0.0
# 16553              0.0                    1.0                  0.0
# 34106              0.0                    1.0                  0.0
# 3804               0.0                    1.0                  0.0
# 37747              0.0                    1.0                  0.0
#
#        certification_NR  certification_PG  certification_PG-13  \
# 9538                0.0               0.0                  0.0
# 16553               0.0               0.0                  0.0
# 34106               0.0               0.0                  0.0
# 3804                0.0               0.0                  0.0
# 37747               0.0               0.0                  0.0
#
#        certification_R  adult  budget  popularity  runtime  vote_average  \
# 9538               0.0    0.0     0.0       0.600     70.0           0.0
# 16553              0.0    0.0     0.0       9.087    100.0           6.1
# 34106              0.0    0.0    10.0       1.842     89.0           4.5
# 3804               0.0    0.0     0.0       1.092     97.0           0.0
# 37747              0.0    0.0     0.0       1.209     98.0           2.8
#
#        vote_count    year  month   day  belongs_to_collection  \
# 9538          0.0  2007.0   10.0  24.0                    0.0
# 16553       141.0  2018.0   12.0   7.0                    0.0
# 34106         4.0  2012.0    3.0  18.0                    0.0
# 3804          0.0  2008.0    8.0   7.0                    0.0
Durbin-Watson:                   1.995
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        770125451.231
# Skew:                          14.528   Prob(JB):                         0.00
# Kurtosis:                     642.536   Cond. No.                     6.06e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.25e-13. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
## Get train data performance from skearn to confirm matches OLS


## Get test data performance

# %% [markdown]
# # Improving Our Model:

# %% [markdown]
# > "Garbage In = Garbage Out"
#
#
# - Before we dive into iterating on our model, I realized there were some big issues that I did not account for in the original data.
#     - some movies may not have been released.
#     - We should probably remove movies with 0 budget and revenue.

# %%
## reload the data
df = pd.read_csv('../Data/combined_tmdb_data.csv.gz',lineterminator='\n')
df = df.set_index('imdb_id')
df.head(2)
# Out:
#            adult                     backdrop_path belongs_to_collection  \
# imdb_id
# tt0312305    0.0                               NaN                   NaN
# tt0326965    0.0  /xt2klJdKCVGXcoBGQrGfAS0aGDE.jpg                   NaN
#
#            budget                                             genres  \
# imdb_id
# tt0312305     0.0  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# tt0326965     0.0  [{'id': 53, 'name': 'Thriller'}, {'id': 9648, ...
#
#                              homepage       id original_language  \
# imdb_id
# tt0312305  http://www.qqthemovie.com/  23738.0                en
# tt0326965    http://www.inmysleep.com  40048.0                en
#
#                                    original_title  \
# imdb_id
# tt0312305  Quantum Quest: A Cassini Space Odyssey
# tt0326965                             In My Sleep
#
#                                                     overview  popularity  \
# imdb_id
# tt0312305  Dave, a young photon, who is forced out of the...       2.769
# tt0326965  Marcus (Philip WInchester) wakes up in the mid...       6.120
#
#                                 poster_path production_companies  \
# imdb_id
# tt0312305  /wflqNWF3BCwWJABjIbGWeM9hKHP.jpg                   []
# tt0326965  /sv9o6VYUQM2AbfmlTwDTn9238R5.jpg                   []
#
#                                         production_countries release_date  \
# imdb_id
# tt0312305  [{'iso_3166_1': 'US', 'name': 'United States o...   2012-12-02
# tt0326965  [{'iso_3166_1': 'US', 'name': 'United States o...   2010-04-23
#
#            revenue  runtime  \
# imdb_id
# tt0312305      0.0     45.0
# tt0326965      0.0     90.0
#
#                                             spoken_languages    status  \
# imdb_id
# tt0312305  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# tt0326965  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                               tagline                                   title  \
# imdb_id
# tt0312305                         NaN  Quantum Quest: A Cassini Space Odyssey
# tt0326965  Sleepwalking Can Be Deadly                             In My Sleep
#
#            video  vote_average  vote_count certification
# imdb_id
# tt0312305    0.0           8.4         7.0           NaN
# tt0326965    0.0           5.5        31.0         PG-13

# %% [markdown]
# ### Repeating Feature Engineering

# %%
## Columns to exclude - Keeping Status and companies
drop_cols = ['backdrop_path','backdrop_path','original_title','overview',
                 'poster_path','tagline','id','homepage', #'status','production_companies'
                 'production_countries','video','spoken_languages',
            'original_language']
df = df.drop(columns=drop_cols)

## Use .notna() to get True if it belongs to a collection
df['belongs_to_collection'] = df['belongs_to_collection'].notna()

## Function to get just the genre names as a list 
import json
def get_genre_name(x):
    x = x.replace("'",'"')
    x = json.loads(x)
    
    genres = []
    for genre in x:
        genres.append(genre['name'])
    return genres

## Use ourn function and exploding the new column
df['genres_list'] = df['genres'].apply(get_genre_name)
df_explode = df.explode('genres_list')

## save unique genres
unique_genres = df_explode['genres_list'].dropna().unique()

## Manually One-Hot-Encode Genres
for genre in unique_genres:
    df[f"Genre_{genre}"] = df['genres'].str.contains(genre,regex=False)    


## Drop original genre cols
df = df.drop(columns=['genres','genres_list'])


#### Fixing Certification
## Checking Certification values
df['certification'].value_counts(dropna=False)
# fix extra space certs
df['certification'] = df['certification'].str.strip()

## fix certification col
repl_cert = {'UR':'NR',
             'Not Rated':'NR',
             'Unrated':'NR',
             '-':'NR',
             '10':np.nan,
             'ScreamFest Horror Film Festival':'NR'}
df['certification'] = df['certification'].replace(repl_cert)
df['certification'].value_counts(dropna=False)


#### Converting year to sep features
## split release date into 3 columns
new_cols = ['year','month','day']
df[new_cols] = df['release_date'].str.split('-',expand=True)
df[new_cols] = df[new_cols].astype(float)

## drop original feature
df = df.drop(columns=['release_date'])
df
# Out:
#            adult  belongs_to_collection       budget  popularity  \
# imdb_id
# tt0312305    0.0                  False          0.0       2.769
# tt0326965    0.0                  False          0.0       6.120
# tt0331312    0.0                  False          0.0       0.600
# tt0393049    0.0                  False     300000.0       2.418
# tt0398286    0.0                  False  260000000.0     119.168
# ...          ...                    ...          ...         ...
# tt7661128    0.0                  False          0.0       0.600
# tt7786614    0.0                  False          0.0       0.600
# tt8170758    0.0                  False          0.0       0.600
# tt9330112    0.0                  False          0.0       1.201
# tt9556198    0.0                   True          0.0       0.840
#
#                                         production_companies      revenue  \
# imdb_id
# tt0312305                                                 []          0.0
# tt0326965                                                 []          0.0
# tt0331312                                                 []          0.0
# tt0393049  [{'id': 46102, 'logo_path': None, 'name': 'Ill...          0.0
# tt0398286  [{'id': 6125, 'logo_path': '/tVPmo07IHhBs4Huil...  592461732.0
# ...                                                      ...          ...
# tt7661128  [{'id': 117146, 'logo_path': None, 'name': 'JE...     250000.0
# tt7786614                                                 []          0.0
# tt8170758                                                 []          0.0
# tt9330112                                                 []          0.0
# tt9556198  [{'id': 64599, 'logo_path': None, 'name': 'SRS...          0.0
#
#            runtime    status                                   title  \
# imdb_id
# tt0312305     45.0  Released  Quantum Quest: A Cassini Space Odyssey
# tt0326965     90.0  Released                             In My Sleep
# tt0331312      0.0  Released                      This Wretched Life
# tt0393049     98.0  Released                        Anderson's Cross
# tt0398286    100.0  Released                                 Tangled
# ...            ...       ...                                     ...
# tt7661128     77.0  Released                          Cold by Nature
# tt7786614    100.0  Released                                  Tattoo
# tt8170758     61.0  Released         The Swell Season: One Step Away
# tt9330112    145.0  Released                      Ninaithale Inikkum
# tt9556198     80.0  Released                  Deep Sea Monster Raiga
#
#            vote_average  vote_count certification  Genre_Family  \
# imdb_id
# tt0312305           8.4         7.0           NaN          True
# tt0326965           5.5        31.0         PG-13         False
# tt0331312           5.0         1.0           NaN         False
# tt0393049           4.0         5.0           NaN         False
# tt0398286           7.6      9364.0            PG          True
# ...                 ...         ...           ...           ...
# tt7661128           0.0         0.0         PG-13         False
# tt7786614           5.0         1.0           NaN         False
# tt8170758           0.0         0.0            NR         False
# tt9330112           4.0         1.0           NaN         False
# tt9556198           7.7         3.0           NaN         False
#
#            Genre_Animation  Genre_Science Fiction  Genre_Thriller  \
# imdb_id
# tt0312305             True                   True           False
# tt0326965            False                  False            True
# tt0331312            False                  False           False
# tt0393049            False                  False           False
# tt0398286             True                  False           False
# ...                    ...                    ...             ...
# tt7661128            False                  False            True
# tt7786614            False                  False           False
# tt8170758            False                  False           False
# tt9330112            False                  False            True
# tt9556198            False                  False           False
#
#            Genre_Mystery  Genre_Drama  Genre_Romance  Genre_Comedy  Genre_War  \
# imdb_id
# tt0312305          False        False          False         False      False
# tt0326965           True         True          False         False      False
# tt0331312          False        False          False         False      False
# tt0393049          False         True           True          True      False
# tt0398286          False        False          False         False      False
# ...                  ...          ...            ...           ...        ...
# tt7661128          False        False          False         False      False
# tt7786614          False        False          False         False      False
# tt8170758          False        False          False         False      False
# tt9330112           True         True          False         False      False
# tt9556198          False        False          False         False      False
#
#            Genre_Crime  Genre_Action  Genre_Adventure  Genre_Horror  \
# imdb_id
# tt0312305        False         False            False         False
# tt0326965        False         False            False         False
# tt0331312        False         False            False         False
# tt0393049        False         False            False         False
# tt0398286        False         False            False         False
# ...                ...           ...              ...           ...
# tt7661128        False         False            False         False
# tt7786614        False         False            False         False
# tt8170758        False         False            False         False
# tt9330112        False         False            False         False
# tt9556198        False          True            False         False
#
#            Genre_Fantasy  Genre_History  Genre_Western  Genre_Music  \
# imdb_id
# tt0312305          False          False          False        False
# tt0326965          False          False          False        False
# tt0331312          False          False          False        False
# tt0393049          False          False          False        False
# tt0398286          False          False          False        False
# ...                  ...            ...            ...          ...
# tt7661128          False          False          False        False
# tt7786614          False          False          False        False
# tt8170758          False          False          False        False
# tt9330112          False          False          False        False
# tt9556198           True          False          False        False
#
#            Genre_Documentary  Genre_TV Movie    year  month   day
# imdb_id
# tt0312305              False           False  2012.0   12.0   2.0
# tt0326965              False           False  2010.0    4.0  23.0
# tt0331312              False           False  2010.0    1.0   1.0
# tt0393049              False           False  2010.0    5.0  20.0
# tt0398286              False           False  2010.0   11.0  24.0
# ...                      ...             ...     ...    ...   ...
# tt7661128              False           False  2009.0    9.0   1.0
# tt7786614              False           False  2009.0    1.0   1.0
# tt8170758              False           False  2009.0   10.0  27.0
# tt9330112              False           False  2009.0    9.0   4.0
# tt9556198              False           False  2009.0    8.0  15.0
#
# [60130 rows x 34 columns]

# %% [markdown]
# ### New Filtering

# %% [markdown]
# - Make sure to only keep:
#     1. Status=Released.
#     2. Budget >0
#     3. Revenue >0

# %%
## Check status
df['status'].value_counts()
# Out:
# Released           60097
# Post Production       27
# In Production          6
# Name: status, dtype: int64

# %%
## Save only Released status
df = df.loc[ df['status'] == 'Released']
df = df.drop(columns=['status'])
df
# Out:
#            adult  belongs_to_collection       budget  popularity  \
# imdb_id
# tt0312305    0.0                  False          0.0       2.769
# tt0326965    0.0                  False          0.0       6.120
# tt0331312    0.0                  False          0.0       0.600
# tt0393049    0.0                  False     300000.0       2.418
# tt0398286    0.0                  False  260000000.0     119.168
# ...          ...                    ...          ...         ...
# tt7661128    0.0                  False          0.0       0.600
# tt7786614    0.0                  False          0.0       0.600
# tt8170758    0.0                  False          0.0       0.600
# tt9330112    0.0                  False          0.0       1.201
# tt9556198    0.0                   True          0.0       0.840
#
#                                         production_companies      revenue  \
# imdb_id
# tt0312305                                                 []          0.0
# tt0326965                                                 []          0.0
# tt0331312                                                 []          0.0
# tt0393049  [{'id': 46102, 'logo_path': None, 'name': 'Ill...          0.0
# tt0398286  [{'id': 6125, 'logo_path': '/tVPmo07IHhBs4Huil...  592461732.0
# ...                                                      ...          ...
# tt7661128  [{'id': 117146, 'logo_path': None, 'name': 'JE...     250000.0
# tt7786614                                                 []          0.0
# tt8170758                                                 []          0.0
# tt9330112                                                 []          0.0
# tt9556198  [{'id': 64599, 'logo_path': None, 'name': 'SRS...          0.0
#
#            runtime                                   title  vote_average  \
# imdb_id
# tt0312305     45.0  Quantum Quest: A Cassini Space Odyssey           8.4
# tt0326965     90.0                             In My Sleep           5.5
# tt0331312      0.0                      This Wretched Life           5.0
# tt0393049     98.0                        Anderson's Cross           4.0
# tt0398286    100.0                                 Tangled           7.6
# ...            ...                                     ...           ...
# tt7661128     77.0                          Cold by Nature           0.0
# tt7786614    100.0                                  Tattoo           5.0
# tt8170758     61.0         The Swell Season: One Step Away           0.0
# tt9330112    145.0                      Ninaithale Inikkum           4.0
# tt9556198     80.0                  Deep Sea Monster Raiga           7.7
#
#            vote_count certification  Genre_Family  Genre_Animation  \
# imdb_id
# tt0312305         7.0           NaN          True             True
# tt0326965        31.0         PG-13         False            False
# tt0331312         1.0           NaN         False            False
# tt0393049         5.0           NaN         False            False
# tt0398286      9364.0            PG          True             True
# ...               ...           ...           ...              ...
# tt7661128         0.0         PG-13         False            False
# tt7786614         1.0           NaN         False            False
# tt8170758         0.0            NR         False            False
# tt9330112         1.0           NaN         False            False
# tt9556198         3.0           NaN         False            False
#
#            Genre_Science Fiction  Genre_Thriller  Genre_Mystery  Genre_Drama  \
# imdb_id
# tt0312305                   True           False          False        False
# tt0326965                  False            True           True         True
# tt0331312                  False           False          False        False
# tt0393049                  False           False          False         True
# tt0398286                  False           False          False        False
# ...                          ...             ...            ...          ...
# tt7661128                  False            True          False        False
# tt7786614                  False           False          False        False
# tt8170758                  False           False          False        False
# tt9330112                  False            True           True         True
# tt9556198                  False           False          False        False
#
#            Genre_Romance  Genre_Comedy  Genre_War  Genre_Crime  Genre_Action  \
# imdb_id
# tt0312305          False         False      False        False         False
# tt0326965          False         False      False        False         False
# tt0331312          False         False      False        False         False
# tt0393049           True          True      False        False         False
# tt0398286          False         False      False        False         False
# ...                  ...           ...        ...          ...           ...
# tt7661128          False         False      False        False         False
# tt7786614          False         False      False        False         False
# tt8170758          False         False      False        False         False
# tt9330112          False         False      False        False         False
# tt9556198          False         False      False        False          True
#
#            Genre_Adventure  Genre_Horror  Genre_Fantasy  Genre_History  \
# imdb_id
# tt0312305            False         False          False          False
# tt0326965            False         False          False          False
# tt0331312            False         False          False          False
# tt0393049            False         False          False          False
# tt0398286            False         False          False          False
# ...                    ...           ...            ...            ...
# tt7661128            False         False          False          False
# tt7786614            False         False          False          False
# tt8170758            False         False          False          False
# tt9330112            False         False          False          False
# tt9556198            False         False           True          False
#
#            Genre_Western  Genre_Music  Genre_Documentary  Genre_TV Movie  \
# imdb_id
# tt0312305          False        False              False           False
# tt0326965          False        False              False           False
# tt0331312          False        False              False           False
# tt0393049          False        False              False           False
# tt0398286          False        False              False           False
# ...                  ...          ...                ...             ...
# tt7661128          False        False              False           False
# tt7786614          False        False              False           False
# tt8170758          False        False              False           False
# tt9330112          False        False              False           False
# tt9556198          False        False              False           False
#
#              year  month   day
# imdb_id
# tt0312305  2012.0   12.0   2.0
# tt0326965  2010.0    4.0  23.0
# tt0331312  2010.0    1.0   1.0
# tt0393049  2010.0    5.0  20.0
# tt0398286  2010.0   11.0  24.0
# ...           ...    ...   ...
# tt7661128  2009.0    9.0   1.0
# tt7786614  2009.0    1.0   1.0
# tt8170758  2009.0   10.0  27.0
# tt9330112  2009.0    9.0   4.0
# tt9556198  2009.0    8.0  15.0
#
# [60097 rows x 33 columns]

# %%
## filter out financials that don't have financial data
df = df.loc[(df['budget'] >0 ) & (df['revenue']>0)]
df
# Out:
#            adult  belongs_to_collection       budget  popularity  \
# imdb_id
# tt0398286    0.0                  False  260000000.0     119.168
# tt0411951    0.0                   True   30000000.0      70.694
# tt0427152    0.0                  False   69000000.0      21.747
# tt0429493    0.0                  False  110000000.0      56.494
# tt0435761    0.0                   True  200000000.0      93.983
# ...          ...                    ...          ...         ...
# tt1532382    0.0                   True    3500000.0       4.838
# tt1542960    0.0                  False     300000.0       1.937
# tt1560950    0.0                   True        600.0       1.795
# tt1565058    0.0                   True     125000.0       5.989
# tt1569364    0.0                  False   10000000.0       6.687
#
#                                         production_companies       revenue  \
# imdb_id
# tt0398286  [{'id': 6125, 'logo_path': '/tVPmo07IHhBs4Huil...  5.924617e+08
# tt0411951  [{'id': 5882, 'logo_path': None, 'name': 'Namc...  9.670000e+05
# tt0427152  [{'id': 2242, 'logo_path': None, 'name': 'Ever...  8.638786e+07
# tt0429493  [{'id': 10908, 'logo_path': None, 'name': 'Pho...  1.772388e+08
# tt0435761  [{'id': 3, 'logo_path': '/1TjvGVDMYsj6JBxOAkUH...  1.066970e+09
# ...                                                      ...           ...
# tt1532382                                                 []  3.704408e+06
# tt1542960  [{'id': 46722, 'logo_path': None, 'name': 'Gol...  2.000000e+05
# tt1560950                                                 []  3.000000e+00
# tt1565058  [{'id': 4580, 'logo_path': None, 'name': 'Cine...  3.470000e+06
# tt1569364  [{'id': 1038, 'logo_path': '/o62j8ZNXmRTrq6Thv...  2.150000e+07
#
#            runtime                     title  vote_average  vote_count  \
# imdb_id
# tt0398286    100.0                   Tangled           7.6      9364.0
# tt0411951     92.0                    Tekken           5.4       553.0
# tt0427152    114.0       Dinner for Schmucks           5.6      1452.0
# tt0429493    117.0                The A-Team           6.4      3877.0
# tt0435761    103.0               Toy Story 3           7.8     12455.0
# ...            ...                       ...           ...         ...
# tt1532382     97.0        Hooked on the Game           6.3        42.0
# tt1542960    122.0  The Figurine (Araromire)           4.2        11.0
# tt1560950     81.0                   D@bbe 2           1.9        10.0
# tt1565058     88.0            A Blood Pledge           5.4        40.0
# tt1569364    102.0           Black Lightning           6.1       135.0
#
#           certification  Genre_Family  Genre_Animation  Genre_Science Fiction  \
# imdb_id
# tt0398286            PG          True             True                  False
# tt0411951             R         False            False                   True
# tt0427152         PG-13         False            False                  False
# tt0429493         PG-13         False            False                  False
# tt0435761             G          True             True                  False
# ...                 ...           ...              ...                    ...
# tt1532382           NaN         False            False                   True
# tt1542960           NaN         False            False                  False
# tt1560950           NaN         False            False                  False
# tt1565058           NaN         False            False                  False
# tt1569364            NR         False            False                  False
#
#            Genre_Thriller  Genre_Mystery  Genre_Drama  Genre_Romance  \
# imdb_id
# tt0398286           False          False        False          False
# tt0411951            True          False         True          False
# tt0427152           False          False        False          False
# tt0429493            True          False        False          False
# tt0435761           False          False        False          False
# ...                   ...            ...          ...            ...
# tt1532382           False          False        False          False
# tt1542960           False           True         True          False
# tt1560950           False           True        False          False
# tt1565058           False          False        False          False
# tt1569364           False          False        False          False
#
#            Genre_Comedy  Genre_War  Genre_Crime  Genre_Action  \
# imdb_id
# tt0398286         False      False        False         False
# tt0411951         False      False         True          True
# tt0427152          True      False        False         False
# tt0429493          True      False         True          True
# tt0435761          True      False        False         False
# ...                 ...        ...          ...           ...
# tt1532382         False      False        False          True
# tt1542960         False      False        False         False
# tt1560950         False      False        False         False
# tt1565058         False      False        False         False
# tt1569364         False      False        False          True
#
#            Genre_Adventure  Genre_Horror  Genre_Fantasy  Genre_History  \
# imdb_id
# tt0398286            False         False          False          False
# tt0411951            False         False          False          False
# tt0427152            False         False          False          False
# tt0429493             True         False          False          False
# tt0435761            False         False          False          False
# ...                    ...           ...            ...            ...
# tt1532382            False         False          False          False
# tt1542960            False          True          False          False
# tt1560950            False          True          False          False
# tt1565058            False          True          False          False
# tt1569364            False         False          False          False
#
#            Genre_Western  Genre_Music  Genre_Documentary  Genre_TV Movie  \
# imdb_id
# tt0398286          False        False              False           False
# tt0411951          False        False              False           False
# tt0427152          False        False              False           False
# tt0429493          False        False              False           False
# tt0435761          False        False              False           False
# ...                  ...          ...                ...             ...
# tt1532382          False        False              False           False
# tt1542960          False        False              False           False
# tt1560950          False        False              False           False
# tt1565058          False        False              False           False
# tt1569364          False        False              False           False
#
#              year  month   day
# imdb_id
# tt0398286  2010.0   11.0  24.0
# tt0411951  2010.0    3.0  20.0
# tt0427152  2010.0    7.0  30.0
# tt0429493  2010.0    6.0   9.0
# tt0435761  2010.0    6.0  16.0
# ...           ...    ...   ...
# tt1532382  2009.0   11.0  26.0
# tt1542960  2009.0   10.0   2.0
# tt1560950  2009.0   12.0  24.0
# tt1565058  2009.0    6.0  18.0
# tt1569364  2009.0   12.0  31.0
#
# [5090 rows x 33 columns]

# %% [markdown]
# ### Production Company

# %%
df['production_companies']
# Out:
# imdb_id
# tt0398286    [{'id': 6125, 'logo_path': '/tVPmo07IHhBs4Huil...
# tt0411951    [{'id': 5882, 'logo_path': None, 'name': 'Namc...
# tt0427152    [{'id': 2242, 'logo_path': None, 'name': 'Ever...
# tt0429493    [{'id': 10908, 'logo_path': None, 'name': 'Pho...
# tt0435761    [{'id': 3, 'logo_path': '/1TjvGVDMYsj6JBxOAkUH...
#                                    ...
# tt1532382                                                   []
# tt1542960    [{'id': 46722, 'logo_path': None, 'name': 'Gol...
# tt1560950                                                   []
# tt1565058    [{'id': 4580, 'logo_path': None, 'name': 'Cine...
# tt1569364    [{'id': 1038, 'logo_path': '/o62j8ZNXmRTrq6Thv...
# Name: production_companies, Length: 5090, dtype: object

# %%
## getting longest string to check for multiple companies
idxmax = df['production_companies'].apply(len).idxmax()
idxmax
# Out:
# 'tt0168629'

# %%
test = df.loc[idxmax, 'production_companies']
test
# Out:
# "[{'id': 53671, 'logo_path': None, 'name': 'Lantia Cinema & Audiovisivi', 'origin_country': ''}, {'id': 8, 'logo_path': '/78ilmDNTpdCfsakrsLqmAUkFTrO.png', 'name': 'Fine Line Features', 'origin_country': ''}, {'id': 76, 'logo_path': '/nebkQYtQKhZyHJfh5v0oGpNbPzu.png', 'name': 'Zentropa Entertainments', 'origin_country': 'DK'}, {'id': 119, 'logo_path': '/1di2gITGUZr730AMuMKiCrP90Vl.png', 'name': 'DR', 'origin_country': 'DK'}, {'id': 157, 'logo_path': None, 'name': 'SVT Drama', 'origin_country': ''}, {'id': 201, 'logo_path': '/6UIpEURdjnmcJPwgTDRzVRuwADr.png', 'name': 'ARTE', 'origin_country': 'FR'}, {'id': 321, 'logo_path': '/pfp6VWF3tYfOHHVRHpYe2iGcYrf.png', 'name': 'Memfis Film', 'origin_country': 'SE'}, {'id': 591, 'logo_path': '/q5I5RDwMEiqoNmfaJgd2LraEOJY.png', 'name': 'France 3 Cinéma', 'origin_country': 'FR'}, {'id': 2996, 'logo_path': None, 'name': 'Angel films', 'origin_country': ''}, {'id': 5975, 'logo_path': '/vvjgoKygWWYZvYyidT3RmOCq5If.png', 'name': 'YLE', 'origin_country': 'FI'}, {'id': 7330, 'logo_path': None, 'name': 'Blind Spot Pictures', 'origin_country': 'FI'}, {'id': 8659, 'logo_path': '/96hCWEsfmTZQsoUap0CcG21qaA.png', 'name': 'VPRO', 'origin_country': 'NL'}, {'id': 11239, 'logo_path': None, 'name': 'Liberator Productions', 'origin_country': 'FR'}, {'id': 14937, 'logo_path': None, 'name': 'Íslenska kvikmyndasamsteypan', 'origin_country': 'IS'}, {'id': 30268, 'logo_path': None, 'name': 'Pain Unlimited GmbH Filmproduktion', 'origin_country': ''}, {'id': 53667, 'logo_path': None, 'name': 'Trust Film Svenska', 'origin_country': ''}, {'id': 53668, 'logo_path': None, 'name': 'Cinematograph A/S', 'origin_country': ''}, {'id': 53669, 'logo_path': None, 'name': 'What Else? B.V', 'origin_country': ''}, {'id': 53670, 'logo_path': None, 'name': 'Filmek A/S', 'origin_country': ''}, {'id': 6705, 'logo_path': '/e8EXNSfwr5E9d3TR8dHKbQnQK4W.png', 'name': 'Film4 Productions', 'origin_country': 'GB'}, {'id': 104, 'logo_path': '/9aotxauvc9685tq9pTcRJszuT06.png', 'name': 'Canal+', 'origin_country': 'FR'}, {'id': 94, 'logo_path': '/huC7HqorvUThGIrENrbcHmQVUA0.png', 'name': 'ARTE France Cinéma', 'origin_country': 'FR'}, {'id': 2801, 'logo_path': '/bswb1PLLsKDUXMLgy42bZtCtIde.png', 'name': 'Film i Väst', 'origin_country': 'SE'}, {'id': 447, 'logo_path': None, 'name': 'TV 1000 Sverige', 'origin_country': 'SE'}, {'id': 46, 'logo_path': '/3xFdKHLXPGHEbrAkmsepGE8974Y.png', 'name': 'WDR', 'origin_country': 'DE'}, {'id': 47, 'logo_path': '/i7Z9ot2o3N5Sa3HrF09kniFs2y8.png', 'name': 'Constantin Film', 'origin_country': 'DE'}]"

# %%
# using regular expressions to extrap just the name
import re
exp= r"\'name\'\:.?\'(\w*.*?)\'"
re.findall(exp, test)
# Out:
# ['Lantia Cinema & Audiovisivi',
#  'Fine Line Features',
#  'Zentropa Entertainments',
#  'DR',
#  'SVT Drama',
#  'ARTE',
#  'Memfis Film',
#  'France 3 Cinéma',
#  'Angel films',
#  'YLE',
#  'Blind Spot Pictures',
#  'VPRO',
#  'Liberator Productions',
#  'Íslenska kvikmyndasamsteypan',
#  'Pain Unlimited GmbH Filmproduktion',
#  'Trust Film Svenska',
#  'Cinematograph A/S',
#  'What Else? B.V',
#  'Filmek A/S',
#  'Film4 Productions',
#  'Canal+',
#  'ARTE France Cinéma',
#  'Film i Väst',
#  'TV 1000 Sverige',
#  'WDR',
#  'Constantin Film']

# %%
def get_prod_company_names(x):
    if x=='[]':
        return ["MISSING"]
    
    exp= r"\'name\'\:.?\'(\w*.*?)\'"
    companies = re.findall(exp, x)
    return companies

# %%
## test function
get_prod_company_names(test)
# Out:
# ['Lantia Cinema & Audiovisivi',
#  'Fine Line Features',
#  'Zentropa Entertainments',
#  'DR',
#  'SVT Drama',
#  'ARTE',
#  'Memfis Film',
#  'France 3 Cinéma',
#  'Angel films',
#  'YLE',
#  'Blind Spot Pictures',
#  'VPRO',
#  'Liberator Productions',
#  'Íslenska kvikmyndasamsteypan',
#  'Pain Unlimited GmbH Filmproduktion',
#  'Trust Film Svenska',
#  'Cinematograph A/S',
#  'What Else? B.V',
#  'Filmek A/S',
#  'Film4 Productions',
#  'Canal+',
#  'ARTE France Cinéma',
#  'Film i Väst',
#  'TV 1000 Sverige',
#  'WDR',
#  'Constantin Film']

# %%
## Save new clean prod_comapny col and explode
df['prod_company'] = df['production_companies'].apply(get_prod_company_names)
prod_companies = df['prod_company'].explode()
prod_companies.value_counts().head(49)
# Out:
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/4230646071.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['prod_company'] = df['production_companies'].apply(get_prod_company_names)
# Universal Pictures           285
# Warner Bros. Pictures        281
# Columbia Pictures            234
# 20th Century Fox             195
# Paramount                    178
# MISSING                      167
# Canal+                       152
# New Line Cinema              143
# Walt Disney Pictures         135
# Relativity Media             123
# Lionsgate                    121
# DreamWorks Pictures           99
# Metro-Goldwyn-Mayer           98
# StudioCanal                   96
# Village Roadshow Pictures     91
# Touchstone Pictures           76
# Miramax                       74
# Summit Entertainment          72
# Dune Entertainment            72
# Screen Gems                   69
# TSG Entertainment             67
# Focus Features                66
# Fox Searchlight Pictures      64
# Sony Pictures                 62
# Regency Enterprises           62
# Working Title Films           56
# Blumhouse Productions         55
# Dimension Films               55
# Legendary Pictures            51
# The Weinstein Company         50
# Millennium Films              50
# Ingenious Media               49
# Ciné+                         49
# Film4 Productions             49
# TF1 Films Production          47
# New Regency Pictures          47
# BBC Films                     47
# Fox 2000 Pictures             45
# Original Film                 44
# Scott Rudin Productions       43
# France 2 Cinéma               43
# CJ Entertainment              43
# EuropaCorp                    41
# Scott Free Productions        40
# Epsilon Motion Pictures       40
# Revolution Studios            39
# DreamWorks Animation          38
# Participant                   38
# Spyglass Entertainment        38
# Name: prod_company, dtype: int64

# %% [markdown]
# - Common Prod Company Encoding:
#     - Keep top 50 most common companies an one hot encode

# %%
## saving the 50 most common companies
common_companies = sorted(prod_companies.value_counts().head(50).index)
common_companies
# Out:
# ['20th Century Fox',
#  'BBC Films',
#  'Blumhouse Productions',
#  'CJ Entertainment',
#  'Canal+',
#  'Ciné+',
#  'Columbia Pictures',
#  'Dimension Films',
#  'DreamWorks Animation',
#  'DreamWorks Pictures',
#  'Dune Entertainment',
#  'Epsilon Motion Pictures',
#  'EuropaCorp',
#  'Film4 Productions',
#  'Focus Features',
#  'Fox 2000 Pictures',
#  'Fox Searchlight Pictures',
#  'France 2 Cinéma',
#  'France 3 Cinéma',
#  'Ingenious Media',
#  'Legendary Pictures',
#  'Lionsgate',
#  'MISSING',
#  'Metro-Goldwyn-Mayer',
#  'Millennium Films',
#  'Miramax',
#  'New Line Cinema',
#  'New Regency Pictures',
#  'Original Film',
#  'Paramount',
#  'Participant',
#  'Regency Enterprises',
#  'Relativity Media',
#  'Revolution Studios',
#  'Scott Free Productions',
#  'Scott Rudin Productions',
#  'Screen Gems',
#  'Sony Pictures',
#  'Spyglass Entertainment',
#  'StudioCanal',
#  'Summit Entertainment',
#  'TF1 Films Production',
#  'TSG Entertainment',
#  'The Weinstein Company',
#  'Touchstone Pictures',
#  'Universal Pictures',
#  'Village Roadshow Pictures',
#  'Walt Disney Pictures',
#  'Warner Bros. Pictures',
#  'Working Title Films']

# %%
## manually ohe top 20 companies
for company in common_companies:
    df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# Out:
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)
# /var/folders/rf/vw4r41jd7vd95x1w0dth7v9h0000gp/T/ipykernel_59253/1813762744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, f"ProdComp_{company}"] = df.loc[:,'production_companies'].str.contains(company, regex=False)

# %%
## Dropping columns
drop_for_model = ['title','prod_company','production_companies']
df = df.drop(columns=drop_for_model)
df
# Out:
#            adult  belongs_to_collection       budget  popularity  \
# imdb_id
# tt0398286    0.0                  False  260000000.0     119.168
# tt0411951    0.0                   True   30000000.0      70.694
# tt0427152    0.0                  False   69000000.0      21.747
# tt0429493    0.0                  False  110000000.0      56.494
# tt0435761    0.0                   True  200000000.0      93.983
# ...          ...                    ...          ...         ...
# tt1532382    0.0                   True    3500000.0       4.838
# tt1542960    0.0                  False     300000.0       1.937
# tt1560950    0.0                   True        600.0       1.795
# tt1565058    0.0                   True     125000.0       5.989
# tt1569364    0.0                  False   10000000.0       6.687
#
#                 revenue  runtime  vote_average  vote_count certification  \
# imdb_id
# tt0398286  5.924617e+08    100.0           7.6      9364.0            PG
# tt0411951  9.670000e+05     92.0           5.4       553.0             R
# tt0427152  8.638786e+07    114.0           5.6      1452.0         PG-13
# tt0429493  1.772388e+08    117.0           6.4      3877.0         PG-13
# tt0435761  1.066970e+09    103.0           7.8     12455.0             G
# ...                 ...      ...           ...         ...           ...
# tt1532382  3.704408e+06     97.0           6.3        42.0           NaN
# tt1542960  2.000000e+05    122.0           4.2        11.0           NaN
# tt1560950  3.000000e+00     81.0           1.9        10.0           NaN
# tt1565058  3.470000e+06     88.0           5.4        40.0           NaN
# tt1569364  2.150000e+07    102.0           6.1       135.0            NR
#
#            Genre_Family  Genre_Animation  Genre_Science Fiction  \
# imdb_id
# tt0398286          True             True                  False
# tt0411951         False            False                   True
# tt0427152         False            False                  False
# tt0429493         False            False                  False
# tt0435761          True             True                  False
# ...                 ...              ...                    ...
# tt1532382         False            False                   True
# tt1542960         False            False                  False
# tt1560950         False            False                  False
# tt1565058         False            False                  False
# tt1569364         False            False                  False
#
#            Genre_Thriller  Genre_Mystery  Genre_Drama  Genre_Romance  \
# imdb_id
# tt0398286           False          False        False          False
# tt0411951            True          False         True          False
# tt0427152           False          False        False          False
# tt0429493            True          False        False          False
# tt0435761           False          False        False          False
# ...                   ...            ...          ...            ...
# tt1532382           False          False        False          False
# tt1542960           False           True         True          False
# tt1560950           False           True        False          False
# tt1565058           False          False        False          False
# tt1569364           False          False        False          False
#
#            Genre_Comedy  Genre_War  Genre_Crime  Genre_Action  \
# imdb_id
# tt0398286         False      False        False         False
# tt0411951         False      False         True          True
# tt0427152          True      False        False         False
# tt0429493          True      False         True          True
# tt0435761          True      False        False         False
# ...                 ...        ...          ...           ...
# tt1532382         False      False        False          True
# tt1542960         False      False        False         False
# tt1560950         False      False        False         False
# tt1565058         False      False        False         False
# tt1569364         False      False        False          True
#
#            Genre_Adventure  Genre_Horror  Genre_Fantasy  Genre_History  \
# imdb_id
# tt0398286            False         False          False          False
# tt0411951            False         False          False          False
# tt0427152            False         False          False          False
# tt0429493             True         False          False          False
# tt0435761            False         False          False          False
# ...                    ...           ...            ...            ...
# tt1532382            False         False          False          False
# tt1542960            False          True          False          False
# tt1560950            False          True          False          False
# tt1565058            False          True          False          False
# tt1569364            False         False          False          False
#
#            Genre_Western  Genre_Music  Genre_Documentary  Genre_TV Movie  \
# imdb_id
# tt0398286          False        False              False           False
# tt0411951          False        False              False           False
# tt0427152          False        False              False           False
# tt0429493          False        False              False           False
# tt0435761          False        False              False           False
# ...                  ...          ...                ...             ...
# tt1532382          False        False              False           False
# tt1542960          False        False              False           False
# tt1560950          False        False              False           False
# tt1565058          False        False              False           False
# tt1569364          False        False              False           False
#
#              year  month   day  ProdComp_20th Century Fox  ProdComp_BBC Films  \
# imdb_id
# tt0398286  2010.0   11.0  24.0                      False               False
# tt0411951  2010.0    3.0  20.0                      False               False
# tt0427152  2010.0    7.0  30.0                      False               False
# tt0429493  2010.0    6.0   9.0                       True               False
# tt0435761  2010.0    6.0  16.0                      False               False
# ...           ...    ...   ...                        ...                 ...
# tt1532382  2009.0   11.0  26.0                      False               False
# tt1542960  2009.0   10.0   2.0                      False               False
# tt1560950  2009.0   12.0  24.0                      False               False
# tt1565058  2009.0    6.0  18.0                      False               False
# tt1569364  2009.0   12.0  31.0                      False               False
#
#            ProdComp_Blumhouse Productions  ProdComp_CJ Entertainment  \
# imdb_id
# tt0398286                           False                      False
# tt0411951                           False                      False
# tt0427152                           False                      False
# tt0429493                           False                      False
# tt0435761                           False                      False
# ...                                   ...                        ...
# tt1532382                           False                      False
# tt1542960                           False                      False
# tt1560950                           False                      False
# tt1565058                           False                      False
# tt1569364                           False                      False
#
#            ProdComp_Canal+  ProdComp_Ciné+  ProdComp_Columbia Pictures  \
# imdb_id
# tt0398286            False           False                       False
# tt0411951            False           False                       False
# tt0427152            False           False                       False
# tt0429493            False           False                       False
# tt0435761            False           False                       False
# ...                    ...             ...                         ...
# tt1532382            False           False                       False
# tt1542960            False           False                       False
# tt1560950            False           False                       False
# tt1565058            False           False                       False
# tt1569364            False           False                       False
#
#            ProdComp_Dimension Films  ProdComp_DreamWorks Animation  \
# imdb_id
# tt0398286                     False                          False
# tt0411951                     False                          False
# tt0427152                     False                          False
# tt0429493                     False                          False
# tt0435761                     False                          False
# ...                             ...                            ...
# tt1532382                     False                          False
# tt1542960                     False                          False
# tt1560950                     False                          False
# tt1565058                     False                          False
# tt1569364                     False                          False
#
#            ProdComp_DreamWorks Pictures  ProdComp_Dune Entertainment  \
# imdb_id
# tt0398286                         False                        False
# tt0411951                         False                        False
# tt0427152                          True                        False
# tt0429493                         False                         True
# tt0435761                         False                        False
# ...                                 ...                          ...
# tt1532382                         False                        False
# tt1542960                         False                        False
# tt1560950                         False                        False
# tt1565058                         False                        False
# tt1569364                         False                        False
#
#            ProdComp_Epsilon Motion Pictures  ProdComp_EuropaCorp  \
# imdb_id
# tt0398286                             False                False
# tt0411951                             False                False
# tt0427152                             False                False
# tt0429493                             False                False
# tt1532382                          False                           False
# tt1542960                          False                           False
# tt1560950                          False                           False
# tt1565058                          False                           False
# tt1569364                          False                           False
#
#            ProdComp_Working Title Films
# imdb_id
# tt0398286                         False
# tt0411951                         False
# tt0427152                         False
# tt0429493                         False
# tt0435761                         False
# ...                                 ...
# tt1532382                         False
# tt1542960                         False
# tt1560950                         False
# tt1565058                         False
# tt1569364                         False
#
# [5090 rows x 81 columns]

# %%
def get_train_test_split(df_, y_col='revenue',drop_cols=[]):
    
    ## Make copy of input df
    df = df_.copy()
    
    ## filter columns in drop cols (if exist)
    final_drop_cols = []
    [df.drop(columns=c,inplace=True) for c in df.columns if c in drop_cols]
    
    
    ## Make x and y variables
    y = df[y_col].copy()
    X = df.drop(columns=[y_col]).copy()

    X_train, X_test, y_train, y_test = train_test_split(X,y)#, random_state=321)
    

    
    ## make cat selector and using it to save list of column names
    cat_select = make_column_selector(dtype_include='object')
    cat_cols = cat_select(X_train)


    ## make num selector and using it to save list of column names
    num_select = make_column_selector(dtype_include='number')
    num_cols = num_select(X_train)


    ## select manually OHE cols for later
    bool_select = make_column_selector(dtype_include='bool')
    already_ohe_cols = bool_select(X_train)

    ## convert manual ohe to int
    X_train[already_ohe_cols] = X_train[already_ohe_cols].astype(int)
    X_test[already_ohe_cols] = X_test[already_ohe_cols].astype(int)

    ## make pipelines
    cat_pipe = make_pipeline(SimpleImputer(strategy='constant',
                                           fill_value='MISSING'),
                             OneHotEncoder(handle_unknown='ignore', sparse=False))
    num_pipe = make_pipeline(SimpleImputer(strategy='mean'),#StandardScaler()
                            )

    preprocessor = make_column_transformer((num_pipe, num_cols),
                                           (cat_pipe,cat_cols),remainder='passthrough')
    
    

    ## fit the col transformer
    preprocessor.fit(X_train)

    ## Finding the categorical pipeline in our col transformer.
    preprocessor.named_transformers_['pipeline-2']

    ## B) Using list-slicing to find the encoder 
    cat_features = preprocessor.named_transformers_['pipeline-2'][-1].get_feature_names_out(cat_cols)


    ## Create the empty list
    final_features = [*cat_features,*num_cols,*already_ohe_cols]

    ## Make df verisons of x data
    X_train_tf = pd.DataFrame( preprocessor.transform(X_train), 
                              columns=final_features, index=X_train.index)


    X_test_tf = pd.DataFrame( preprocessor.transform(X_test),
                             columns=final_features, index=X_test.index)


    ### Adding a Constant for Statsmodels
    ## Make final X_train_df and X_test_df with constants added
    X_train_df = sm.add_constant(X_train_tf, prepend=False, has_constant='add')
    X_test_df = sm.add_constant(X_test_tf, prepend=False, has_constant='add')
    return X_train_df, y_train, X_test_df, y_test

# %% [markdown]
# ## Model with Updated Features

# %%
X_train_df, y_train, X_test_df, y_test = get_train_test_split(df)

## instantiate an OLS model WITH the training data.
model = sm.OLS(y_train, X_train_df)

## Fit the model and view the summary
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                revenue   R-squared:                       0.759
# Model:                            OLS   Adj. R-squared:                  0.754
# Method:                 Least Squares   F-statistic:                     141.8
# Date:                Wed, 15 Jun 2022   Prob (F-statistic):               0.00
# Time:                        17:24:43   Log-Likelihood:                -75566.
# No. Observations:                3817   AIC:                         1.513e+05
# Df Residuals:                    3733   BIC:                         1.518e+05
# Df Model:                          83
# Covariance Type:            nonrobust
# ======================================================================================================
#                                          coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# certification_G                     3.643e+06   9.71e+07      0.038      0.970   -1.87e+08    1.94e+08
# certification_MISSING                  1.8500      0.062     30.002      0.000       1.729       1.971
# certification_NC-17                 1.508e+05   3.43e+04      4.396      0.000    8.36e+04    2.18e+05
# certification_NR                    2.266e+05      9e+04      2.517      0.012    5.01e+04    4.03e+05
# certification_PG                   -3.465e+06   1.52e+06     -2.284      0.022   -6.44e+06   -4.91e+05
# certification_PG-13                 3.033e+04    721.104     42.056      0.000    2.89e+04    3.17e+04
# certification_R                     2.409e+05   3.09e+05      0.779      0.436   -3.65e+05    8.47e+05
# adult                              -1.319e+05   4.69e+05     -0.281      0.779   -1.05e+06    7.89e+05
# budget                              1.455e+05   1.85e+05      0.785      0.433   -2.18e+05    5.09e+05
# ProdComp_Scott Free Productions    -4.507e+07   1.92e+07     -2.351      0.019   -8.27e+07   -7.48e+06
# ProdComp_Scott Rudin Productions   -3.018e+07   1.81e+07     -1.663      0.096   -6.58e+07     5.4e+06
# ProdComp_Screen Gems               -1.096e+07   1.43e+07     -0.764      0.445   -3.91e+07    1.71e+07
# ProdComp_Sony Pictures               1.53e+07   1.33e+07      1.150      0.250   -1.08e+07    4.14e+07
# ProdComp_Spyglass Entertainment    -1.773e+07   1.85e+07     -0.959      0.337    -5.4e+07    1.85e+07
# ProdComp_StudioCanal               -1.092e+06   1.29e+07     -0.085      0.932   -2.63e+07    2.41e+07
# ProdComp_Summit Entertainment      -5.318e+07   1.36e+07     -3.914      0.000   -7.98e+07   -2.65e+07
# ProdComp_TF1 Films Production       -1.65e+07   1.97e+07     -0.836      0.403   -5.52e+07    2.22e+07
# ProdComp_TSG Entertainment          -8.77e+07   1.47e+07     -5.975      0.000   -1.16e+08   -5.89e+07
# ProdComp_The Weinstein Company     -4.495e+07   1.66e+07     -2.703      0.007   -7.75e+07   -1.24e+07
# ProdComp_Touchstone Pictures       -2.369e+06   1.36e+07     -0.174      0.862    -2.9e+07    2.43e+07
# ProdComp_Universal Pictures         4.534e+05   7.32e+06      0.062      0.951   -1.39e+07    1.48e+07
# ProdComp_Village Roadshow Pictures -2.673e+07   1.34e+07     -1.992      0.046    -5.3e+07   -4.28e+05
# ProdComp_Walt Disney Pictures      -1.168e+07    1.2e+07     -0.970      0.332   -3.53e+07    1.19e+07
# ProdComp_Warner Bros. Pictures     -3.802e+07   8.02e+06     -4.739      0.000   -5.37e+07   -2.23e+07
# ProdComp_Working Title Films       -2.429e+07   1.64e+07     -1.477      0.140   -5.65e+07    7.96e+06
# const                              -4.483e+08   5.43e+08     -0.825      0.409   -1.51e+09    6.17e+08
# ==============================================================================
# Omnibus:                     3606.137   Durbin-Watson:                   1.982
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           440700.252
# Skew:                           4.129   Prob(JB):                         0.00
# Kurtosis:                      54.988   Cond. No.                     3.26e+23
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.13e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# # The Assumptions of Linear Regression

# %% [markdown]
# - The 4 Assumptions of a Linear Regression are:
#     - Linearity: That the input features have a linear relationship with the target.
#     - Independence of features (AKA Little-to-No Multicollinearity): That the features are not strongly related to other features.
#     - **Normality: The model's residuals are approximately normally distributed.**
#     - **Homoscedasticity: The model residuals have equal variance across all predictions.**

# %% [markdown]
# ### QQ-Plot for Checking for Normality

# %%
## Create a Q-QPlot

# first calculate residuals 


## then use sm's qqplot

# %% [markdown]
# ### Residual Plot for Checking Homoscedasticity

# %%
## Plot scatterplot with y_hat_test vs resids

# %% [markdown]
# ### Putting it all together

# %%
def evaluate_ols(result,X_train_df, y_train):
    """Plots a Q-Q Plot and residual plot for a statsmodels OLS regression.
    """
    
    ## save residuals from result
    y_pred = result.predict(X_train_df)
    resid = y_train - y_pred
    
    fig, axes = plt.subplots(ncols=2,figsize=(12,5))
    
    ## Normality 
    sm.graphics.qqplot(resid,line='45',fit=True,ax=axes[0]);
    
    ## Homoscedasticity
    ax = axes[1]
    ax.scatter(y_pred, resid, edgecolor='white',lw=1)
    ax.axhline(0,zorder=0)
    ax.set(ylabel='Residuals',xlabel='Predicted Value');
    plt.tight_layout()
    
evaluate_ols(result,X_train_df, y_train)

# %% [markdown]
# > Next class: iterating on our model & interpreting coefficients
